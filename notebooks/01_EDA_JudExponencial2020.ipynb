# %% [markdown]
# # ANALISE EXPLORATORIA DOS DADOS

# %% [markdown]
# ## Carregar os documentos

# %%
import pandas as pd
import json
from bs4 import BeautifulSoup
import unicodedata 
import numpy as np

# %%
def remover_acentos(txt):
    return unicodedata.normalize('NFKD', txt).encode('ASCII', 'ignore').decode('ASCII')

def cleanhtml_beautifulsoup(raw_html):
    cleantext = ''
    if not raw_html is None:
        txt = BeautifulSoup(raw_html.replace("\n"," "), "html.parser").text.lower().replace("  ", "").replace("  ", "").replace("  ", "").replace("  ", "").replace("  ", "").replace("  ", "").replace("  ", "").replace("  ", "").replace("  ", "").replace("  ", "").replace("  ", "").replace("'","")
        cleantext = remover_acentos(txt)
    return cleantext

# %%
# df_npu_2017a = pd.read_csv('metadados2017a.csv', encoding = 'latin1')
# df_npu_2017b = pd.read_csv('metadados2017b.csv', encoding = 'latin1')
# df_npu_2018 = pd.read_csv('metadados2018.csv', encoding = 'latin1')
# df_npu_2019 = pd.read_csv('metadados2019.csv', encoding = 'latin1')
df_npu_2020 = pd.read_csv('metadados2020.csv', encoding = 'latin1')

# %%
# df_2017a = df_npu_2017a.sample(50)
# df_2017a["ds_modelo_documento_limpo"] = df_2017a["ConteÃºdo do Documento"].apply(cleanhtml_beautifulsoup)

# df_2017b = df_npu_2017b.sample(50)
# df_2017b["ds_modelo_documento_limpo"] = df_2017b["ConteÃºdo do Documento"].apply(cleanhtml_beautifulsoup)

# df_2018 = df_npu_2018.sample(50)
# df_2018["ds_modelo_documento_limpo"] = df_2018["ConteÃºdo do Documento"].apply(cleanhtml_beautifulsoup)

# df_2019 = df_npu_2019.sample(50)
# df_2019["ds_modelo_documento_limpo"] = df_2019["ConteÃºdo do Documento"].apply(cleanhtml_beautifulsoup)

df_2020 = df_npu_2020.sample(150)
df_2020["ds_modelo_documento_limpo"] = df_2020["ConteÃºdo do Documento"].apply(cleanhtml_beautifulsoup)

# %%
# # 2017a
# for k in range(0, 51):
#   df_2017a[k:k+1]['ds_modelo_documento_limpo'].to_csv(f'/content/drive/My Drive/Colab Notebooks/datasets/andreza/andreza{k}.csv')

# for k in range(0, 51):
#   df_2017b[k:k+1]['ds_modelo_documento_limpo'].to_csv(f'/content/drive/My Drive/Colab Notebooks/datasets/samara/samara{k}.csv')  

# for k in range(0, 51):
#   df_2018[k:k+1]['ds_modelo_documento_limpo'].to_csv(f'/content/drive/My Drive/Colab Notebooks/datasets/diego/diego{k}.csv')  

# for k in range(0, 51):
#   df_2019[k:k+1]['ds_modelo_documento_limpo'].to_csv(f'/content/drive/My Drive/Colab Notebooks/datasets/carine/carine{k}.csv')  

for k in range(0, 151):
  df_2020[k:k+1]['ds_modelo_documento_limpo'].to_csv(f'/content/drive/My Drive/Colab Notebooks/datasets/Maria/maria{k}.csv')

# %%
"tomate         seco".replace("  ", "")
# Out:
# 'tomate seco'

# %%
df_2020.iloc[34]['ds_modelo_documento_limpo']
# df_2020.iloc[1][1].to_string('/content/drive/My Drive/Colab Notebooks/datasets/Maria/maria.txt')

# %%
np.savetxt(r'/content/drive/My Drive/Colab Notebooks/datasets/Maria/maria.txt', df_2020.iloc[1]['ds_modelo_documento_limpo'].lower(), fmt='%d')

# %%
df_2020["ds_modelo_documento_limpo"]

# %% [markdown]
# ## Criacao das ENTIDADES JURIDICAS

# %%
import spacy
from spacy import displacy

# %%
'''BAIXANDO O MODELO DA LÍNGUA PORTUGUESA'''

# !python -m spacy download pt

# %%
nlp = spacy.load('pt')
ner = nlp.get_pipe("ner")

# %% [markdown]
# ### Primeira abordagem

# %%
ner.add_label('CARGO') 
ner.add_label('TERMO.JURIDICO') 
ner.add_label('CONSTITUICAO.FEDERAL') 
ner.add_label('ADCT') 
ner.add_label('EMENDA.CONSTITUCIONAL') 
ner.add_label('LEI.COMPLEMENTAR') 
ner.add_label('TRATADOS') 
ner.add_label('LEI.ORDINARIA') 
ner.add_label('LEI.DELEGADA') 
ner.add_label('MEDIDA.PROVISORIA') 
ner.add_label('DECRETO.LEGISLATIVO') 
ner.add_label('RESOLUCAO') 
ner.add_label('DECRETO') 
ner.add_label('INSTRUCAO.NORMATIVA') 
ner.add_label('IMPOSTO') 
ner.add_label('SENTENÇA') 
ner.add_label('DESPACHO') 
ner.add_label('DECISAO') 
ner.add_label('ORGAO.PUBLICO') 
ner.add_label('RECURSO.EXTRAORDINARIO')
ner.add_label('PARTE')
ner.add_label('RECURSO')

# %%
TRAIN_DATA =[
('voto o sr.', {
'entities': []
}),
('desembargador federal paulo roberto de oliveira lima (relator): o inconformismo da apelante se volta contra decisum que, em sede de cumprimento provisorio de sentenca, interceptou a peticao inicial, ao argumento de que e descabida a pretensao do contribuinte de obter a execucao dos valores, indevidamente recolhidos a titulo de incidencia de contribuicao previdenciaria patronal sobre o terco constitucional de ferias, antes do transito em julgado da decisao judicial que lhe fora favoravel.', {
'entities': [(0, 13, 'cargo'), (54, 61, 'termo.juridico'), (83, 91, 'parte'), (108, 115, 'termo.juridico'), (132, 154, 'termo.juridico'), (182, 197, 'termo.juridico'), (343, 379, 'imposto'), (429, 448, 'termo.juridico'), (452, 468, 'termo.juridico')]
}),
('no caso concreto, verifica-se que o feito ainda nao transitara em julgado quando da sentenca.', {
'entities': [(52, 73, 'termo.juridico')]
}),
('dai que, por mais forte que seja a tese juridica da demandante em sua acao principal, fundada que esta inclusive em tese firmada pelo stf, em sede de repercussao geral, nao e suficiente para afastar o obstaculo de que os creditos que se pretendem executar ainda carecem de atendimento do requisito legal de transito em julgado da citada decisao em que reconhecidos, consoante bem decidiu o juizo de primeiro grau de jurisdicao.', {
'entities': [(52, 62, 'parte'), (70, 84, 'termo.juridico'), (134, 137, 'orgao.publico'), (150, 167, 'termo.juridico'), (307, 326, 'termo.juridico'), (416, 426, 'termo.juridico')]
}),
('com efeito, quando o executado e a fazenda publica e a obrigacao de pagar se refere a quantia certa, o entendimento assente e a nao aplicacao do artigo 520 do cpc, por forca do que a carta magna dispoe acerca do regime de rpv e precatorios.', {
'entities': [(21, 30, 'parte'), (35, 50, 'orgao.publico'), (183, 194, 'constituicao.federal'), (222, 225, 'termo.juridico'), (228, 239, 'termo.juridico')]
}),
('demais disso, a jurisprudencia desta segunda turma sedimentou o seu entendimento, com base no art.', {
'entities': [(16, 30, 'termo.juridico'), (37, 50, 'orgao.publico')]
}),
('100 da constituicao federal, de que as condenacoes referentes a obrigacoes de pagar so devem ocorrer apos o transito em julgado da sentenca, pois sao submetidas ao sistema de pagamento por precatorios.', {
'entities': [(0, 27, 'constituicao.federal'), (108, 127, 'termo.juridico'), (189, 200, 'termo.juridico')]
}),
('como segue: processual civil.', {
'entities': []
}),
('cumprimento de sentenca.', {
'entities': []
}),
('obrigacao de pagar contra a fazenda publica.', {
'entities': []
}),
('inss.', {
'entities': [(0, 4, 'orgao.publico')]
}),
('ausencia de transito em julgado.', {
'entities': [(12, 31, 'termo.juridico')]
}),
('impossibilidade.', {
'entities': []
}),
('beneficio da justica gratuita.', {
'entities': []
}),
('possibilidade.', {
'entities': []
}),
('1. trata-se de apelacao contra sentenca que julgou improcedente o pedido de cumprimento de sentenca, extinguindo-o nos moldes do art.', {
'entities': [(15, 23, 'termo.juridico'), (51, 63, 'termo.juridico')]
}),
('924, i, do cpc/15. entendeu o magistrado que nao se admite o cumprimento provisorio de obrigacao de pagar contra a fazenda publica.', {
'entities': [(11, 14, 'lei.ordinaria'), (30, 40, 'cargo'), (61, 83, 'termo.juridico'), (115, 130, 'orgao.publico')]
}),
('nao houve condenacao ao pagamento de honorarios advocaticios em razao da falta de impugnacao do executado. [...]', {
'entities': [(37, 60, 'termo.juridico'), (82, 92, 'termo.juridico'), (96, 105, 'parte')]
}),
('6. o pretorio excelso firmou o seguinte entendimento no re 573.872/rs: ""a jurisprudencia do stf firmou-se no sentido da inaplicabilidade ao poder publico do regime juridico da execucao provisoria de prestacao de pagar quantia certa, apos o advento da emenda constitucional 30/2000"" (stf, re 573.872/rs, rel.', {
'entities': [(56, 69, 'recurso'), (75, 89, 'termo.juridico'), (93, 96, 'orgao.publico'), (177, 196, 'termo.juridico'), (252, 281, 'emenda.constitucional'), (285, 288, 'orgao.publico'), (290, 303, 'recurso')]
}),
('min.', {
'entities': [(0, 4, 'cargo')]
}),
('edson fachin, tribunal pleno, julgamento: 24/05/2017).', {
'entities': []
}),
('7. a jurisprudencia da segunda turma sedimentou o entendimento, com base no art.', {
'entities': [(5, 19, 'termo.juridico'), (23, 36, 'orgao.publico')]
}),
('100 da constituicao federal, de que as condenacoes referentes a obrigacoes de pagar so devem ocorrer apos o transito em julgado da sentenca, pois sao submetidas ao sistema de pagamento por precatorios (precedente: processo 00037893520154058300, desembargador federal vladimir carvalho, segunda turma, julgamento: 16/10/2018). [...]', {
'entities': [(0, 27, 'constituicao.federal'), (108, 127, 'termo.juridico'), (189, 200, 'termo.juridico'), (245, 258, 'cargo'), (286, 299, 'orgao.publico')]
}),
('10. apelacao parcialmente provida apenas para conceder o beneficio da justica gratuita ao autor/exequente. (', {
'entities': [(4, 12, 'termo.juridico')]
}),
('trf 5 - segunda turma - proc.', {
'entities': [(0, 5, 'orgao.publico'), (8, 21, 'orgao.publico')]
}),
('08053887720184058200 - relator des.', {
'entities': [(23, 30, 'cargo')]
}),
('fed.', {
'entities': []
}),
('leonardo carvalho - d.j. 31.07.2019) constitucional.', {
'entities': []
}),
('base de calculo do pis e da cofins.', {
'entities': [(19, 22, 'imposto'), (28, 34, 'imposto')]
}),
('exclusao do icms.', {
'entities': [(12, 16, 'imposto')]
}),
('entendimento do stf.', {
'entities': [(16, 19, 'orgao.publico')]
}),
('re 574706/pr, sob o rito da repercussao geral.', {
'entities': []
}),
('cumprimento provisorio de sentenca.', {
'entities': []
}),
('pedido de compensacao.', {
'entities': [(0, 21, 'termo.juridico')]
}),
('ausencia de transito em julgado da decisao.', {
'entities': [(12, 31, 'termo.juridico')]
}),
('descabimento.', {
'entities': []
}),
('apelacao desprovida.', {
'entities': []
}),
('1. o inconformismo da apelante se volta contra decisum que, em sede de cumprimento provisorio de sentenca, interceptou a peticao inicial, ao argumento de que e descabida a pretensao do contribuinte de obter a compensacao dos valores, indevidamente recolhidos a titulo de incidencia de icms sobre as contribuicoes ao pis e a cofins, antes do transito em julgado da decisao judicial que lhe fora favoravel.', {
'entities': [(22, 30, 'parte'), (47, 54, 'termo.juridico'), (121, 136, 'termo.juridico'), (285, 289, 'imposto'), (316, 319, 'imposto'), (324, 330, 'imposto'), (341, 360, 'termo.juridico'), (364, 380, 'termo.juridico')]
}),
('2. no caso, foram interpostos, em 24/7/2018, recursos extraordinario e especial pela fazenda nacional em face da decisao que se pretende executar, mas que sequer foram apreciados.', {
'entities': [(45, 79, 'termo.juridico'), (85, 101, 'orgao.publico')]
}),
('dai que, por mais forte que seja a tese juridica da demandante em sua acao principal, fundada que esta em tese firmada pelo stf, em sede de repercussao geral, nao e suficiente para afastar o obstaculo de que os creditos, que se pretende compensar, ainda carecem de atendimento do requisito legal de transito em julgado da citada decisao em que reconhecidos.', {
'entities': [(52, 62, 'parte'), (70, 84, 'termo.juridico'), (124, 127, 'orgao.publico'), (140, 157, 'termo.juridico'), (299, 318, 'termo.juridico')]
}),
('3. com efeito, sobre o tema a jurisprudencia encontra-se pacificada, dado que a corte superior de justica ao julgar o resp 1.164.452/mg e o resp 1.167.039/df, ambos submetidos a sistematica dos recursos repetitivos, firmou entendimento no sentido de que em se tratando de compensacao de credito objeto de controversia judicial, e vedada a sua realizacao ""antes do transito em julgado da respectiva decisao judicial"", consoante preconiza o art.', {
'entities': [(30, 44, 'termo.juridico'), (57, 67, 'termo.juridico'), (80, 105, 'orgao.publico'), (118, 135, 'recurso'), (140, 157, 'recurso'), (194, 214, 'termo.juridico'), (365, 384, 'termo.juridico'), (399, 415, 'termo.juridico')]
}),
('170-a do ctn, sendo certo que tal vedacao se aplica, inclusive, as hipoteses de reconhecida inconstitucionalidade do tributo indevidamente recolhido.', {
'entities': [(0, 12, 'lei.complementar'), (92, 113, 'termo.juridico')]
}),
('4. apelacao desprovida. (', {
'entities': [(3, 11, 'termo.juridico')]
}),
('trf 5 - segunda turma - proc.', {
'entities': [(0, 5, 'orgao.publico'), (8, 21, 'orgao.publico')]
}),
('08103367120184058100 - relator des.', {
'entities': [(23, 30, 'cargo')]
}),
('fed.', {
'entities': []
}),
('paulo roberto de oliveira lima - d.j. 07.01.2019) processual civil.', {
'entities': []
}),
('recurso ao qual se negou seguimento monocraticamente.', {
'entities': [(36, 52, 'termo.juridico')]
}),
('parte beneficiaria da justica gratuita.', {
'entities': []
}),
('concessao na acao de conhecimento.', {
'entities': []
}),
('agravo interno provido.', {
'entities': [(0, 14, 'termo.juridico')]
}),
('admissao do agravo de instrumento com apreciacao do seu merito.', {
'entities': [(12, 33, 'termo.juridico'), (38, 62, 'termo.juridico')]
}),
('cumprimento provisorio de sentenca em face da fazenda publica.', {
'entities': []
}),
('obrigacao de pagar.', {
'entities': []
}),
('impossibilidade.', {
'entities': []
}),
('1. agravo de instrumento interposto contra decisao que, em sede de cumprimento provisorio de sentenca contra a fazenda publica (pje 0806225-14.2018.4.05.8401), determinou a suspensao do feito ate o transito em julgado da sentenca que se pretende executar. [...]', {
'entities': [(3, 24, 'termo.juridico'), (67, 89, 'termo.juridico'), (111, 126, 'orgao.publico'), (198, 217, 'termo.juridico')]
}),
('8. a materia devolvida para analise deste tribunal diz respeito a possibilidade de cumprimento provisorio de sentenca que reconhece a exigibilidade de obrigacao de pagar quantia certa em face da fazenda publica, quando inexistir transito em julgado.', {
'entities': [(83, 105, 'termo.juridico'), (195, 210, 'orgao.publico'), (229, 248, 'termo.juridico')]
}),
('9. quando a executada e a fazenda publica e a obrigacao de pagar refere-se a quantia certa, entende-se pela nao aplicacao do art.', {
'entities': [(26, 41, 'orgao.publico')]
}),
('520 do cpc/2015, por forca daquilo que a carta magna dispoe acerca do regime de rpv e precatorios.10. nesse sentido, menciona-se o julgado desta segunda turma julgadora, com entendimento de que, com lastro no art.', {
'entities': [(0, 15, 'lei.ordinaria'), (41, 52, 'constituicao.federal'), (80, 83, 'termo.juridico'), (145, 158, 'orgao.publico')]
}),
('100 da constituicao federal, as condenacoes referentes a obrigacoes de pagar so devem ocorrer apos o transito em julgado da sentenca, porquanto sao submetidas ao sistema de pagamento por precatorios.', {
'entities': [(0, 27, 'constituicao.federal'), (101, 120, 'termo.juridico'), (187, 198, 'termo.juridico')]
}),
('precedente: trf5, 2a t., pje 00037893520154058300, rel.', {
'entities': [(12, 16, 'orgao.publico')]
}),
('des.', {
'entities': []
}),
('federal vladimir carvalho, julg.', {
'entities': []
}),
('em: 16/10/2018. 11. agravo interno provido, apenas para admitir o agravo de instrumento.', {
'entities': [(20, 34, 'termo.juridico'), (66, 87, 'termo.juridico')]
}),
('12. agravo de instrumento desprovido. (', {
'entities': [(4, 25, 'termo.juridico')]
}),
('trf 5 - segunda turma - proc.', {
'entities': [(0, 5, 'orgao.publico'), (8, 21, 'orgao.publico')]
}),
('08162559120184050000 - relator des.', {
'entities': [(23, 30, 'cargo')]
}),
('fed.', {
'entities': []
}),
('paulo machado cordeiro - d.j. 01.08.2019) por fim, observa-se que, sobre o tema, a jurisprudencia encontra-se pacificada, dado que o stf consolidou a tese, em sede de repercussao geral, no sentido da inaplicabilidade ao poder publico do regime juridico da execucao provisoria de prestacao de pagar quantia certa, apos o advento da emenda constitucional 30/2000, nos autos do re 573.872/rs - tribunal pleno - relator min.', {
'entities': [(83, 97, 'termo.juridico'), (110, 120, 'termo.juridico'), (133, 136, 'orgao.publico'), (167, 184, 'termo.juridico'), (256, 275, 'termo.juridico'), (331, 360, 'emenda.constitucional'), (366, 371, 'termo.juridico'), (375, 388, 'recurso'), (408, 415, 'cargo'), (416, 420, 'cargo')]
}),
('edson fachin - dje.', {
'entities': []
}),
('11.09.2017. transcreve-se ementa do julgado paradigma: recurso extraordinario com repercussao geral.', {
'entities': [(63, 99, 'termo.juridico')]
}),
('direito constitucional financeiro.', {
'entities': []
}),
('sistematica dos precatorios (art.', {
'entities': [(16, 27, 'termo.juridico')]
}),
('100, cf/88).', {
'entities': [(0, 10, 'constituicao.federal')]
}),
('execucao provisoria de debitos da fazenda publica.', {
'entities': []
}),
('obrigacao de fazer.', {
'entities': []
}),
('sentenca com transito em julgado.', {
'entities': [(13, 32, 'termo.juridico')]
}),
('emenda constitucional 30/2000. 1. fixacao da seguinte tese ao tema 45 da sistematica da repercussao geral: ""a execucao provisoria de obrigacao de fazer em face da fazenda publica nao atrai o regime constitucional dos precatorios.""', {
'entities': [(0, 30, 'emenda.constitucional'), (88, 105, 'termo.juridico'), (111, 130, 'termo.juridico'), (164, 179, 'orgao.publico'), (218, 229, 'termo.juridico')]
}),
('2. a jurisprudencia do stf firmou-se no sentido da inaplicabilidade ao poder publico do regime juridico da execucao provisoria de prestacao de pagar quantia certa, apos o advento da emenda constitucional 30/2000. precedentes.', {
'entities': [(5, 19, 'termo.juridico'), (23, 26, 'orgao.publico'), (107, 126, 'termo.juridico'), (182, 212, 'emenda.constitucional')]
}),
('3. a sistematica constitucional dos precatorios nao se aplica as obrigacoes de fato positivo ou negativo, dado a excepcionalidade do regime de pagamento de debitos pela fazenda publica, cuja interpretacao deve ser restrita.', {
'entities': [(36, 47, 'termo.juridico'), (169, 184, 'orgao.publico')]
}),
('por consequencia, a situacao rege-se pela regra geral de que toda decisao nao autossuficiente pode ser cumprida de maneira imediata, na pendencia de recursos nao recebidos com efeito suspensivo.', {
'entities': []
}),
('4. nao se encontra parametro constitucional ou legal que obste a pretensao de execucao provisoria de sentenca condenatoria de obrigacao de fazer relativa a implantacao de pensao de militar, antes do transito em julgado dos embargos do devedor opostos pela fazenda publica.', {
'entities': [(78, 97, 'termo.juridico'), (199, 218, 'termo.juridico'), (256, 271, 'orgao.publico')]
}),
('5. ha compatibilidade material entre o regime de cumprimento integral de decisao provisoria e a sistematica dos precatorios, haja vista que este apenas se refere as obrigacoes de pagar quantia certa.', {
'entities': [(112, 123, 'termo.juridico')]
}),
('6. recurso extraordinario a que se nega provimento. (', {
'entities': [(3, 25, 'termo.juridico')]
}),
('re 573.872/rs - tribunal pleno - relator min.', {
'entities': [(0, 13, 'recurso'), (33, 40, 'cargo'), (41, 45, 'cargo')]
}),
('edson fachin - dje.', {
'entities': []
}),
('11.09.2017) com essas breves consideracoes, nego provimento a apelacao.', {
'entities': [(62, 70, 'termo.juridico')]
}),
('e como voto.', {
'entities': []
}),
('paulo roberto de oliveira lima desembargador federal', {
'entities': [(31, 44, 'cargo')]
})
]

# %%
for _, annotations in TRAIN_DATA:
  for ent in annotations.get("entities"):
    ner.add_label(ent[2])

# %%
# Resume training
optimizer = nlp.resume_training()
move_names = list(ner.move_names)

# List of pipes you want to train
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]

# List of pipes which should remain unaffected in training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
from spacy.util import minibatch, compounding
import random

# Begin training by disabling other pipeline components
with nlp.disable_pipes(*other_pipes) :

  sizes = compounding(1.0, 4.0, 1.001)
  # Training for 30 iterations     
  for itn in range(30):
    # shuffle examples before training
    random.shuffle(TRAIN_DATA)
    # batch up the examples using spaCy's minibatch
    batches = minibatch(TRAIN_DATA, size=sizes)
    # ictionary to store losses
    losses = {}
    for batch in batches:
      texts, annotations = zip(*batch)
      # Calling update() over the iteration
      nlp.update(texts, annotations, sgd=optimizer, drop=0.35, losses=losses)
      print("Losses", losses)
# Out:
# Losses {'ner': 15.75566497661642}
# Losses {'ner': 18.264863880653895}
# Losses {'ner': 22.76468045442626}
# Losses {'ner': 32.213137993534254}
# Losses {'ner': 36.806362273116754}
# Losses {'ner': 39.60549459189804}
# Losses {'ner': 44.37697761410969}
# Losses {'ner': 67.78874778767009}
# Losses {'ner': 92.77377904817924}
# Losses {'ner': 100.8398834937857}
# Losses {'ner': 108.3062081807898}
# Losses {'ner': 109.2209674503646}
# Losses {'ner': 114.88237077428647}
# Losses {'ner': 128.4482314025642}
# Losses {'ner': 145.60901949334738}
# Losses {'ner': 168.98534500529576}
# Losses {'ner': 171.8691683404665}
# Losses {'ner': 179.2171444996108}
# Losses {'ner': 181.11533325244142}
# Losses {'ner': 186.82640492179831}
# Losses {'ner': 229.67327329127926}
# Losses {'ner': 239.13228847163606}
# Losses {'ner': 303.64872796987953}
# Losses {'ner': 304.5519208050119}
# Losses {'ner': 306.00089880509955}
# Losses {'ner': 308.66800628736024}
# Losses {'ner': 358.85309179302936}
# ...

# %%
df_2020.iloc[1]['ds_modelo_documento_limpo']
# df_npu_2020.columns
# Out:
# 'Poder Judiciario Tribunal Regional Federal da 5a Regiao Gabinete do Desembargador Federal Rogerio Fialho Moreira AC 0800145-66.2020.4.05.8400 APELANTE: WENDELL BEZERRA DA CAMARA  ADVOGADO: WDAGNO SANDRO BEZERRA CAMARA  APELADA: CAIXA ECONOMICA FEDERAL - CEF  SENTENCA: JUIZ FEDERAL JANILSON BEZERRA DE SIQUEIRA REL.: DES. FEDERAL CONVOCADO GUSTAVO DE PAIVA GADELHA - 3a TURMA VOTO Recebo a apelacao, considerando presentes os pressupostos intrinsecos e extrinsecos para a admissibilidade do recurso. O impetrante, domiciliado em Extremoz/RN, aprovado em concurso publico para o cargo de Tecnico Bancario Novo da CEF, ajuizou o Mandado de Seguranca em face do Presidente da Caixa Economica Federal, objetivando que lhe fosse assegurada a ordem de classificacao do concurso, de modo a que seja garantido o seu direito a nomeacao para o referido cargo. A sentenca esta em consonancia com o entendimento firmado pelo Plenario deste eg. Tribunal no sentido de que, em se tratando de Mandado de Seguranc
# ...

# %%
df_2020.iloc[1]['ds_modelo_documento_limpo'].lower()
# Out:
# 'poder judiciario tribunal regional federal da 5a regiao gabinete do desembargador federal rogerio fialho moreira ac 0800145-66.2020.4.05.8400 apelante: wendell bezerra da camara  advogado: wdagno sandro bezerra camara  apelada: caixa economica federal - cef  sentenca: juiz federal janilson bezerra de siqueira rel.: des. federal convocado gustavo de paiva gadelha - 3a turma voto recebo a apelacao, considerando presentes os pressupostos intrinsecos e extrinsecos para a admissibilidade do recurso. o impetrante, domiciliado em extremoz/rn, aprovado em concurso publico para o cargo de tecnico bancario novo da cef, ajuizou o mandado de seguranca em face do presidente da caixa economica federal, objetivando que lhe fosse assegurada a ordem de classificacao do concurso, de modo a que seja garantido o seu direito a nomeacao para o referido cargo. a sentenca esta em consonancia com o entendimento firmado pelo plenario deste eg. tribunal no sentido de que, em se tratando de mandado de seguranc
# ...

# %%
# Testing the model
doc = nlp(df_2020.iloc[1]['ds_modelo_documento_limpo'].lower())
print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Entities [('desembargador', 'cargo'), ('juiz', 'cargo'), ('apelacao', 'termo.juridico'), ('impetrante', 'termo.juridico'), ('caixa economica', 'termo.juridico'), ('impetrante', 'termo.juridico'), ('jurisprudencia', 'termo.juridico'), ('desembargador', 'cargo'), ('apelacao', 'termo.juridico'), ('desembargador', 'cargo'), ('desembargador', 'cargo'), ('desembargador', 'cargo'), ('stf', 'orgao.publico'), ('segunda turma', 'orgao.publico'), ('caixa economica', 'termo.juridico'), ('peticao inicial', 'termo.juridico'), ('apelacao', 'termo.juridico'), ('apelacao', 'termo.juridico'), ('desembargador', 'cargo'), ('apelacao', 'termo.juridico')]

# %%
displacy.render(doc, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">poder judiciario tribunal regional federal da 5a regiao gabinete do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     desembargador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">cargo</span>
# </mark>
#  federal rogerio fialho moreira ac 0800145-66.2020.4.05.8400 apelante: wendell bezerra da camara  advogado: wdagno sandro bezerra camara  apelada: caixa economica federal - cef  sentenca:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     juiz
# ...

# %% [markdown]
# ### Segunda abordagem

# %%
'''CLASSE PARA TREINAR O MODELO'''
import random
def train_spacy(data,iterations):
    TRAIN_DATA = data
    nlp = spacy.blank('pt')  
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
    
       
    # add labels
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                nlp.update(
                    [text],  # batch of texts
                    [annotations],  # batch of annotations
                    drop=0.2,  # dropout - make it harder to memorise data
                    sgd=optimizer,  # callable to update weights
                    losses=losses)
    return nlp

# %%
'''MELHORANDO O MODELO'''
TRAIN_DATA = [('Em 15/07/1988 nasceu essa linda criança', {'entities': [(3, 13, 'DATE')]}), 
              ('Data de prisão: 10/01/2018', {'entities': [(16, 26, 'DATE')]}),
              ('No dia 01/02/2016 foi decretada a setença', {'entities': [(7, 17, 'DATE')]}),
              ('A data da festa foi 07/05/2019', {'entities': [(20, 30, 'DATE')]}),                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ('João, portador do cpf 123.456.789-65, foi encontrado', {'entities': [(0, 4, 'PER'), (18, 32, 'CPF')]}),
              ('O cpf 025.412.876-99 pertence a Maria', {'entities': [(6, 20, 'CPF')]}),
              ('pilotando uma ferrari',{'entities':[(14,21,'CARRO')]}),
              ('dirigindo uma ferrari',{'entities':[(14,21,'CARRO')]})
             ]

# %%
my_model = train_spacy(TRAIN_DATA, 20)

document = my_model(text)

print('Original Sentence: %s\n' % (text))
    
displacy.render(document, jupyter=True, style='ent')
