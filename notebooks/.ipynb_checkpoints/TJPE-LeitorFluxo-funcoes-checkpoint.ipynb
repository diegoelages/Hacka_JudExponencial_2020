# %% [markdown]
# <a id='MENU'></a>
# # FUNÇÕES COMUNS DO TJPE-LeitorFluxo
# 1. [**discover_fluxo_XML**](#discover_fluxo_XML) - Lê todos os arquivos XML da pasta informada no parâmetro e monta dataframes  com informações de cada processo lido no xml.<br>
# 2. [**obtemPapelLocalizacao**](#obtemPapelLocalizacao) - Converter a EL de Localizacao x Papel num dicionário<br>
# 3. [**criaGraphoFluxo**](#criaGraphoFluxo) - Cria grapho dos fluxos passados no dataframe.<p>
# [**Uso das funções**](#Uso)

# %%
# Importando as bibliotecas necessárias
import xml.etree.ElementTree as et 
import pandas as pd 
import networkx as nx
import matplotlib.pyplot as plt
import os
from fuzzywuzzy import fuzz
import psycopg2

# %%
pd.set_option('max_colwidth', 800)
pd.set_option('display.max_rows', 99999999)

# %% [markdown]
# <a id='discover_fluxo_XML'></a>
# ### Procedimento: discover_fluxo_XML
# [**MENU**](#MENU) - Volta para o menu principal
#
# ***
#
# **OBJETIVO:** Lê todos os arquivos XML da pasta passada como parâmetro e monta uma tabela com informações básicas do fluxo, tais como: 'Processo', 'No origem', 'Tipo', 'Transicao','No destino','Sub-process','Raia', 'Condicao'.<br>
# **PARÂMETROS:**
# * varpath: Pasta onde os arquivos de fluxo no formato xml estão armazenadas.
# * verbose: Quando True, indica que mensagens de aviso serão exibidas durante a execução do procedimento. Utilizado para "depurar" a execução do procedimento. Default=False.
#
# **RETORNO:** df: Dataframe com informações dos fluxos; dfr: Dataframe com informação sobre as raias dos fluxos.
# ***

# %%
def discover_fluxo_XML(varpath, verbose=False): 
    for root, dirs, files in os.walk(varpath, topdown=False):
        rows = []
        raias = []
        tarefas = []
        for name in files:
            print(os.path.join(root, name))
            xtree = et.parse(os.path.join(root, name))
            xroot = xtree.getroot()
            processo = ''
            subprocesso = ''
            nome = ''
            tipo = ''
            nomeraia = ''
            raiatarefa = ''
            regras = ''
            regradecisao=''
            regratransicao=''
      
            for child in xroot.iter('*'):
                if verbose == True:
                    print(child.tag, ' -' , child.tail, '-', child.keys, '-', child.attrib)
                if ('process-definition' in child.tag):
                    processo = child.attrib.get('name')

                # obter raias

                if ("}swimlane" in child.tag) and ("Nó de Desvio" not in child.attrib.get('name')):
                    nomeraia = child.attrib.get('name')

                if ("}assignment" in child.tag):
                    regras = child.attrib.get('pooled-actors')
               
                if(nomeraia!='') and (regras != ''):
                    raias.append({'Processo': processo, 'Raia': nomeraia, 'EL': regras})
                    nomeraia = ''
                    regras = ''
                
                if ("}condition" in child.tag) and (child.attrib.get('expression')!="#{true}"): 
                    rows[-1] = {'Processo': processo, 'No origem': nome, 'Tipo': tipo, 'Transicao': transition, 'No destino':node, 'Sub-process':subprocesso, 'Raia':raiatarefa, 'Condicao':child.attrib.get('expression')}
                
                if ("}event" in child.tag):
                    nome = ''  
                    subprocesso = ''  

                if ("}sub-process" in child.tag) and ("Nó de Desvio" not in child.tag):
                    subprocesso = child.attrib.get('name')

                if ("}task" in child.tag) and (child.attrib.get('name')=='Tarefa inicial'):
                    nome = child.attrib.get('name')
                    tipo = 'start-state'
                
                if ("}task" in child.tag):
                    raiatarefa = child.attrib.get('swimlane')        

                if ("}task-node" in child.tag) and ("Nó de Desvio" in child.attrib.get('name')):
                    nome = ''
                    tipo = ''

                if ("}task-node" in child.tag) and ("Nó de Desvio" not in child.attrib.get('name')):
                    nome = child.attrib.get('name')
                    tipo = "task-node"
                    tarefas.append({'Processo':processo, 'Tarefa':nome})

                if ("}node" in child.tag) and ("Nó de Desvio" not in child.tag):
                    nome = child.attrib.get('name')
                    tipo = "node"

                if ("}process-state" in child.tag) and ("Nó de Desvio" not in child.tag):
                    nome = child.attrib.get('name')
                    tipo = "process-state"

                if ("}join" in child.tag) and ("Nó de Desvio" not in child.tag):
                    nome = child.attrib.get('name')
                    tipo = "join"

                if ("}fork" in child.tag) and ("Nó de Desvio" not in child.tag):
                    nome = child.attrib.get('name')
                    tipo = "fork"

                if ("}decision" in child.tag) and ("Nó de Desvio" not in child.tag):
                    nome = child.attrib.get('name')
                    regradecisao = child.attrib.get('expression')
                    regratransicao = regradecisao[regradecisao.find('?'):regradecisao.find(':',regradecisao.find('?'))]
                    regratransicao = regratransicao[regratransicao.find("'")+1:regratransicao.find("'",5)]  
                    if (verbose == True):
                        print(f'Regratransicao:{regratransicao}')
                    tipo = "decision"

                if ("}transition" in child.tag) and (nome != "") and ("Nó de Desvio" not in child.attrib.get('name')):
                    transition = child.attrib.get('name')
                    node = child.attrib.get('to')
                    if tipo!='task-node':
                        raiatarefa = ''
                    if (verbose == True):
                        print(f'regradecisao:{regradecisao}\t regratransicao:{regratransicao}\t node:{node}')
                    if (transition.strip(" ")== regratransicao.strip(" ")):
                        rows.append({'Processo': processo, 'No origem': nome, 'Tipo': tipo, 'Transicao': transition, 'No destino':node, 'Sub-process':subprocesso, 'Raia':raiatarefa, 'Condicao':regradecisao})
                        regradecisao=''
                        regratransicao=''
                    else:
                        rows.append({'Processo': processo, 'No origem': nome, 'Tipo': tipo, 'Transicao': transition, 'No destino':node, 'Sub-process':subprocesso, 'Raia':raiatarefa, 'Condicao':''})


                    if subprocesso != '':
                        subprocesso = ''
    
        out_df = pd.DataFrame(rows, columns=['Processo', 'No origem','Tipo', 'Transicao','No destino','Sub-process','Raia', 'Condicao'])
        out_ra = pd.DataFrame(raias, columns=['Processo', 'Raia', 'EL'])
        out_ta = pd.DataFrame(tarefas, columns=['Processo', 'Tarefa'])
    return out_df, out_ra, out_ta

# %% [markdown]
# <a id='obtemPapelLocalizacao'></a>
# ### Procedimento: obtemPapelLocalizacao
# [**MENU**](#MENU) - Volta para o menu principal
#
# ***
#
# **OBJETIVO:** Converter a EL referente a atribuição de LOCALIZAÇÃO:PAPEL num dicionário.br>
# **PARÂMETROS:**
# * df_raias: Dataframe de raias retornado pela função: discover_fluxo_XML. <p>
# Exemplo:<br>
#     Transformar: #localizacaoAssignment.getPooledActors('5:1469,1230:1469, 10210:5537,1229:5607,11:5607')}	<br>
#     Em: {'5': '1469', '1230': '1469', '11': '5607', '1229': '5607', '1231': '5534', '1389': '5534', '10206': '5537', '10210': '5537'}
#
# **RETORNO:** df: Dataframe com a mesma estrutura passada no parâmetro de entrada, acrescido da coluna EL_limpa.
# ***

# %%
def obtemPapelLocalizacao(df):
    # Exemplo: "#{localizacaoAssignment.getPooledActors('5:1469,1230:1469,11:1338,1229:1338,1229:5532,1231:5186,1231:5534,1389:5186,1389:5534,10206:5171,10206:5537,10210:5171,10210:5537,1229:5607,11:5607')}"
    def limparElPapelLocalizacao(texto):
        texto_limpo = texto
        texto_limpo = texto_limpo.replace("}","")
        texto_limpo = texto_limpo.replace(")","")
        texto_limpo = texto_limpo.replace("#{localizacaoAssignment.getPooledActors(","")
        texto_limpo = texto_limpo.replace(":","':'")
        texto_limpo = texto_limpo.replace(",","','")
        lista = eval("{"+texto_limpo+"}")
        return lista 
    
    dflocalizacao = pd.read_csv('../dados/df_localizacao_1_grau.csv', encoding='utf-8')
    dflocalizacao.set_index(['id_localizacao'], inplace=True)
    dfpapel = pd.read_csv('../dados/df_papel_1_grau.csv', encoding='utf-8')
    dfpapel.set_index(['id_papel'], inplace=True)

    df_temp = df
    df_temp['EL_limpa'] = df_temp.apply(lambda x: limparElPapelLocalizacao(x['EL']), axis=1)
    
    dados = []
    ds_localizacao = ''
    ds_papel = ''
    for index, row in df_temp.iterrows():
        lista =  row['EL_limpa'] 
        for localizacao, papel in lista.items():
            try:
                ds_localizacao = dflocalizacao.loc[int(localizacao), 'ds_localizacao']
                ds_papel = dfpapel.loc[int(papel), 'ds_nome']            
                dados.append({'Processo':row['Processo'], 'Raia': row['Raia'], 'Localizacao':ds_localizacao, 'Papel':ds_papel})
            except:
                pass
    
    out_df = pd.DataFrame(dados, columns=['Processo', 'Raia', 'Localizacao','Papel'])

    return out_df

# %% [markdown]
# <a id='criaGraphoFluxo'></a>
# ### Procedimento: criaGraphoFluxo
# [**MENU**](#MENU) - Volta para o menu principal
#
# ***
#
# **OBJETIVO:** Cria o grapho de rede dos fluxos passados no parametro (dataframe)<br>
# **PARÂMETROS:**
# * df: Dataframe com informações do fluxo retornado pela função: discover_fluxo_XML. <p>
#
# **RETORNO:** g: grapho.
# ***

# %%
def criaGraphoFluxo(df):
    G = nx.DiGraph( )
    arestas = df.values   # todo filtrar apenas os no que nao sao de subfluxo
    label = []
    listaprocesso = df.Processo.unique().tolist() 
    maximo = len(listaprocesso)-1
    for aresta in arestas:
        # Caso sub-processo, incluir ligacao com o subfluxo
        indice = listaprocesso.index(aresta[0])
        normalizado = (indice - 0) / (maximo - 0)
        if (aresta[2] == 'process-state') :
            try:
                # tarefa do processo para a primeira tarfa do sub-processo 
                print(aresta[5])
                tarefainicial = df[(df['Processo']==aresta[5]) & (df['No origem']=='Tarefa inicial')]['No destino'].values[0]
                print(tarefainicial)
                G.add_node(aresta[1], cor=str(listaprocesso.index(aresta[0])),processo=aresta[0], tipo=aresta[2], raia= '' if aresta[6] is None else aresta[6])
                G.add_edge(aresta[1], tarefainicial,label=aresta[3], origem = aresta[1], destino=aresta[4], condicao=aresta[7])
                label.append({aresta[2]:aresta[2]})
            except:
                print(">>>>>>>>>> possível fluxo inexistente em: {}".format(aresta[5]))    
            
            try:
                # termino do sub-processo para a proxima tarefa do processo que chamou
                G.add_node("Término", cor=str(listaprocesso.index(aresta[5])),processo=aresta[5], tipo="end-state", raia= '')
                G.add_edge("Término", aresta[4] ,label="Término", origem = "Témino", destino=aresta[4], condicao="")
                label.append({"Término":"Término"})
            except:
                print(">>>>>>>>>> possível fluxo inexistente em: {}".format(aresta[5]))    
        else:
            G.add_node(aresta[1], cor=str(listaprocesso.index(aresta[0])), processo=aresta[0], tipo=aresta[2], raia= '' if aresta[6] is None else aresta[6])
            G.add_edge(aresta[1], aresta[4], label=aresta[3], origem = aresta[1], destino=aresta[4], condicao=aresta[7])
            label.append({aresta[2]:aresta[2]})
    return G

# %%
df_traducao = pd.read_excel('../dados/depara_condicoes.xlsx', sep=',', sheet_name="Depara", encoding='utf-8')
dft = pd.read_excel('../dados/depara_condicoes.xlsx', sep=',', sheet_name="Depara", encoding='utf-8')

# %%
def traduzCondicao(condicao):
    try:
        print(f'c:{condicao}')
        traducao = dft[dft['DE']==condicao]['PARA'].values[0]
    except:
        traducao = '' 
    print(f't:{traducao}')
    return traducao

# %% [markdown]
# <a id='Uso'></a>
# ## Utilização das funções acima
# [**MENU**](#MENU) - Volta para o menu principal.

# %%
df, dfr, dfta = discover_fluxo_XML('../fluxos/1_grau')
df_locpap = obtemPapelLocalizacao(dfr[~dfr['EL'].isnull()])

df.to_csv('../dados/df_1_grau.csv', index = False, encoding='utf-8')
dfr.to_csv('../dados/dfr_1_grau.csv', index = False, encoding='utf-8')
dfta.to_csv('../dados/df_tarefas_1_grau.csv', index = False, encoding='utf-8')
df_locpap.to_csv('../dados/df_locpap_1_grau.csv', index = False, encoding='utf-8')

# Monta o grapho
# Out:
# ../fluxos/1_grau\Fluxo2G - 37 - RIS - Remeter para instância superior (PRODUCAO).xml
# ../fluxos/1_grau\FluxoArq - 59 - ARQJEC - Fluxo arquivo de juizados (PRODUCAO).xml
# ../fluxos/1_grau\FluxoArq - 60 - ARQVARAS - Fluxo arquivo de varas (PRODUCAO).xml
# ../fluxos/1_grau\FluxoArq - 61 - ARQGERAL - Fluxo arquivo geral (PRODUCAO).xml
# ../fluxos/1_grau\FluxoJEC - 01 - CA - Controle de Audiencia - (PRODUCAO).xml
# ../fluxos/1_grau\FluxoJEC - 02 - JEC_PAC_CI - PAC - Citar (Inicial) - (PRODUCAO).xml
# ../fluxos/1_grau\FluxoJEC - 03 - JEC_PAC1 - Preparar ato de comunicacao - 1 - (PRODUCAO).xml
# ../fluxos/1_grau\FluxoJEC - 04 - JEC_PAJ1 - Preparar ato judicial - 1 - (PRODUCAO).xml
# ../fluxos/1_grau\FluxoJEC - 05 - EMBT - Embargos de Terceiro - (PRODUCAO).xml
# ../fluxos/1_grau\FluxoJEC - 06 - FCS - Fluxo de Cumprimento de Sentenca - (PRODUCAO).xml
# ../fluxos/1_grau\FluxoJEC - 07 - JEC - Juizados Especiais Civeis - (PRODUCAO).xml
# ../fluxos/1_grau\FluxoMIG - 94 - MIG_FB - Fluxo básico de migração (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 26 - ADP - Avaliar decisão proferida (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 27 - PAJ-P - Preparar ato judicial (Padrão) (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 28 - CD - Cumprimento de decisão (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 29 - RPF - Realizar providências finais (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 30 - VC_FB - Fluxo básico em vara cível (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 42 - PAC-JIF - Preparar ato de comunicação - JIF (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 43 - REMOORG - Remeter para outro órgão (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 44 - DEVOORI - Devolver para o órgão de origem (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 47 - PARTILHA - Fluxo partilha (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 48 - CONTADOR - Fluxo cálculo da contadoria (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 49 - PERICIA-AP - Fluxo perícia apoio psicossocial (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 50 - PERICIA-DS - Fluxo perícia da diretoria de saúde (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 55 - PRATCARTREV - Preparar ato de cartório com revisor (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 56 - REMCONT - Fluxo remeter para contadoria (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 57 - REMAP - Fluxo remeter para apoio psicossocial (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 58 - REMPART - Fluxo remeter para setor de partilha (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 76 - CJIF - Fluxo conciliação do juizado informal de família (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 77 - CP - Controle de Perícia (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 86 - DEPROORG - Deslocamento de processo para outro órgão (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 87 - EQUIPEMD - Fluxo equipe multidisciplinar (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 88 - REMEMD - Fluxo remeter para equipe multidisciplinar (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 89 - NIJ - Fluxo do núcleo da infância e juventude (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 90 - REMNIJ - Fluxo remeter para o núcleo da infância e juventude (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 91 - FJR - Fluxo justiça restaurativa (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 92 - FACFR - Fluxo alteração de classe e fluxo com redistribuição (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 95 - PVAM - Preparar vários atos - Magistrado (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 96 - PVAS - Preparar vários atos - Secretaria (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVC - 99 - RET - Remessa Externa Temporária (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 08 - SB_AVAL_DEC - Avaliação de decisão proferida em execução fiscal (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 09 - FLX_BLOQEXEC - Fluxo de bloqueio de ativos do devedor (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 10 - CONTPRAZO - Controle de prazos (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 11 - FLX_LIBATDEV - Fluxo de liberação de ativos do devedor (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 12 - PRATCART - Preparar ato de cartório (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 13 - PAJ_INICIALEF - Apreciação de recebimento de execução fiscal (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 14 - PAJ - Preparar ato judicial (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 15 - PAC - Preparar ato de comunicação (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 16 - PACCONTP - Preparar comunicação com controle de prazo (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 17 - PAJREC - Preparar ato judicial em recurso (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 18 - AVALBENS - Avaliação de bens (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 19 - CUMPRIDECEF - Cumprimento geral em execução fiscal (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 20 - FLX_DECINTAG - Decisão com cumprimento simples (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 21 - CUMPR_EXEC - Cumprimento de decisão em execução (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 22 - FINEXECFISC - Finalização de execução fiscal (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 23 - FLX_EF - Execução fiscal (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 24 - INCEXEC - Incidentes em execução fiscal (PRODUCAO).xml
# ../fluxos/1_grau\FluxoVEFM - 41 - PRATORD - Preparar ato ordinatório (PRODUCAO).xml
# ../fluxos/1_grau\TJPE_PJe_1G_Ordem_34 - FluxoVC - PAC-SM - Preparar ato de comunicação - SM (PRODUCAO).xml
# ../fluxos/1_grau\TJPE_PJe_1G_Ordem_35 - FluxoVC - SM - Seção de mutirão (PRODUCAO).xml
# C:\Users\diego\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dft[dft['DE']=="#{comunicacaoProcessualAction.getExpedientesEletronico().size() > 0 ? 'Encaminhar Via Sistema' : 'JoinComunicacao'}"]['PARA'].values[0]
# Out:
# 'Condição 20'

# %%
df['CondicaoTratada'] = df.apply(lambda x: traduzCondicao(x['Condicao']), axis=1)
# Out:
# c:
# t:
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:#{(processoParteExpedienteManager.recuperaExpedientesAbertosPorMeiosComunicacaoAndProcessoTrf(null, processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo'))).size > 0) and !('[5186][5366][5534]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 2
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:
# t:
# c:
# t:
# c:#{'Definitivo'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:arquivo:tipoArquivamento')) ? 'Definitivo': 'Testar redistribuição'}
# t:Condição 3
# c:
# t:
# c:#{'Definitivo (redistribuição)'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:arquivo:tipoArquivamento')) ? 'Definitivo redistribuição': 'Testar cancelamento de protocolamento'}
# t:Condição 4
# c:
# t:
# c:#{'Definitivo (cancelamento de protocolamento)'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:arquivo:tipoArquivamento')) ? 'Definitivo (cancelamento de protocolamento)': 'Testar arquivo definitivo (PC N. 29-2019)'}
# t:Condição 5
# c:
# t:
# c:#{'Definitivo (PC N. 29-2019)'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:arquivo:tipoArquivamento')) ? 'Definitivo (PC N. 29-2019)': 'Definitivo (carta precatória)'}
# t:Condição 6
# c:
# t:
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:
# t:
# c:
# t:
# c:#{'Definitivo'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:arquivo:tipoArquivamento')) ? 'Definitivo': 'Testar redistribuição'}
# t:Condição 3
# c:
# t:
# c:#{'Definitivo (redistribuição)'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:arquivo:tipoArquivamento')) ? 'Definitivo redistribuição': 'Testar cancelamento de protocolamento'}
# t:Condição 4
# c:
# t:
# c:#{'Definitivo (cancelamento de protocolamento)'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:arquivo:tipoArquivamento')) ? 'Definitivo (cancelamento de protocolamento)': 'Testar arquivo definitivo (PC N. 29-2019)'}
# t:Condição 5
# c:
# t:
# c:#{'Definitivo (PC N. 29-2019)'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:arquivo:tipoArquivamento')) ? 'Definitivo (PC N. 29-2019)': 'Definitivo (carta precatória)'}
# t:Condição 6
# c:
# t:
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEJurisdicoesJuizados.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']'))) ? 'Arquivo de juizados': 'Arquivo de varas'}
# t:Condição 7
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesEletronico().size() > 0 ? 'Encaminhar Via Sistema [JEC_PAC_CI]' : 'JoinComunicacao [JEC_PAC_CI]'}
# t:
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesCorreios().size() > 0 ? 'Encaminhar Correspondência [JEC_PAC_CI]' : 'JoinComunicacao [JEC_PAC_CI]'}
# t:
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesMandados().size() > 0 ? 'Enviar Mandado [JEC_PAC_CI]' : 'JoinComunicacao [JEC_PAC_CI]'}
# t:
# c:
# t:
# c:#{processoExpedienteHome.buscaCentralMandado().size()>0}
# t:Condição 23
# c:#{processoExpedienteHome.buscaCentralMandado().size()<=0}
# t:Condição 24
# c:
# t:
# c:#{processoExpedienteHome.buscaCentralMandado().size()>1 ? 'Selecionar Central de Mandado' : 'Gerar movimentação mandado'}
# t:Condição 143
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesEletronico().size() > 0 ? 'Encaminhar Via Sistema [JECPAC1]' : 'JoinComunicacao [JECPAC1]'}
# t:
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesCorreios().size() > 0 ? 'Encaminhar Correspondência [JECPAC1]' : 'JoinComunicacao [JECPAC1]'}
# t:
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesMandados().size() > 0 ? 'Enviar Mandado [JECPAC1]' : 'JoinComunicacao [JECPAC1]'}
# t:
# c:
# t:
# c:#{processoExpedienteHome.buscaCentralMandado().size()>0}
# t:Condição 23
# c:#{processoExpedienteHome.buscaCentralMandado().size()<=0}
# t:Condição 24
# c:
# t:
# c:#{processoExpedienteHome.buscaCentralMandado().size()>1 ? 'Selecionar Central de Mandado' : 'Gerar movimentação mandado'}
# t:Condição 143
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{org.jboss.seam.bpm.processInstance.contextInstance.getVariable('TipoMinutaJECPAJ1')=='Minuta_Despacho_Inicial' ? 'Concluso para Despacho Inicial [JEC_PAJ1]' : 'É Minuta Tutela?'}
# t:
# c:
# t:
# c:
# t:
# c:#{org.jboss.seam.bpm.processInstance.contextInstance.getVariable('TipoMinutaJECPAJ1')=='Minuta_Tutela' ? 'Concluso para Decisão Tutela [JEC_PAJ1]' : 'Classificar Conclusão [JEC_PAJ1]'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{processoTrfHome.instance().possuiEventoTestandoExcludente('Magistrado', 'Conclusão') ? 'Término' : 'Ato do Magistrado [JECPAJ1]'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{processoTrfHome.instance().possuiEventoTestandoExcludente('Magistrado', 'Conclusão') ? 'Término' : 'Ato do Magistrado (Despacho Inicial) [JECPAJ1]'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{processoTrfHome.instance().possuiEventoTestandoExcludente('Magistrado', 'Conclusão') ? 'Término' : 'Ato do Magistrado (Tutela) [JECPAJ1]'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:remessaCancelada') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:remessaCancelada')) ? 'Finalizar Preparar Ato Judicial' : 'Classificar conclusão PAJ'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo')).getClasseJudicial().getCodClasseJudicial() == '156' or processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo')).getClasseJudicial().getCodClasseJudicial() == '1114' ? 'Receber na Execução' : 'Classificar conclusão PAJ'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{processoTrfHome.possuiCompetencia(12)}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo')).getClasseJudicial().getCodClasseJudicial() == '156' or processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo')).getClasseJudicial().getCodClasseJudicial() == '1114'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{processoTrfHome.possuiCompetencia(12)}
# t:
# c:#{processoTrfHome.possuiCompetencia(12)}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{processoTrfHome.possuiCompetencia(12)}
# t:
# c:#{processoTrfHome.possuiCompetencia(12)}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:remessaCancelada') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:remessaCancelada')) ? 'Finalizar Preparar Ato Judicial' : 'Classificar conclusão PAJ'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{processoTrfHome.possuiCompetencia(12)}
# t:
# c:#{processoTrfHome.possuiCompetencia(12)}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{processoTrfHome.possuiCompetencia(12)}
# t:
# c:#{processoTrfHome.possuiCompetencia(12)}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{processoTrfHome.possuiCompetencia(12)}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{tramitacaoProcessualService.sigiloso() or tramitacaoProcessualService.temUrgencia() ? 'Conclusão para decisão (urgência)' : 'PAC - Citar (Inicial)'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{('[1]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 118
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{('[1338][1469][5532][5545][5546][5186][5534][5197][5533]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 89
# c:#{(processoParteExpedienteManager.recuperaExpedientesAbertosPorMeiosComunicacaoAndProcessoTrf(null, processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo'))).size > 0) and !('[5186][5366][5534]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 2
# c:#{('[1][5364][5368]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEFACFRPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 126
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuiçãoCancelada') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuiçãoCancelada') ? 'Cancelada' : 'Continuar'}
# t:Condição 127
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{'total'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:bloqueio')) ? 'Ato de Secretaria' : 'Classificar conclusão PAJ'}
# t:
# c:
# t:
# c:
# t:
# c:#{'recusada'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:liberacao')) ? 'Classificar conclusão PAJ' : 'Ato de Secretaria'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal') or (''.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal')))}
# t:Condição 31
# c:
# t:
# c:
# t:
# c:#{(empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal') or (''.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal')))) ? 'Juntada vazia' : 'Juntada não vazia'}
# t:Condição 32
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:remessaCancelada') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:remessaCancelada')) ? 'Finalizar Preparar Ato Judicial' : 'Analisar retorno da instância superior'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not (pjeFluxoTJPEJurisdicoesNaoEnviamContadoria.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']')))}
# t:Condição 92
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ConclusoSentenca') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ConclusoSentenca') and not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:Suspenso') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:Suspenso')) ? 'Retornar' : 'Continuar'}
# t:
# c:
# t:
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:MarcarComoSegredoJustica') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:MarcarComoSegredoJustica')) ? 'Marcar' : 'Desmarcar'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:EnviarParaApensarProcesso') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:EnviarParaApensarProcesso')) ? 'Apensar' : 'Retornar'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal') or (''.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal')))}
# t:Condição 31
# c:
# t:
# c:
# t:
# c:#{(empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal') or (''.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal')))) ? 'Juntada vazia' : 'Juntada não vazia'}
# t:Condição 32
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ConclusoSentenca') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ConclusoSentenca')) ? 'Processo concluso' : 'Testar processo suspenso'}
# t:
# c:
# t:
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:Suspenso') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:Suspenso')) ? 'Processo suspenso' : 'Processo migrado'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1469) and not empty processoHome.getUltimoProcessoEvento(processoTrfHome.instance.processo, 'Julgamento') and ((not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and not tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')))}
# t:Condição 132
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1469) and ((not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')))}
# t:Condição 133
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') ? 'Intimar de julgamento' : 'Triagem'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and processoTrfHome.instance.classeJudicial.codClasseJudicial == '12137'}
# t:Condição 122
# c:#{('[1]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 118
# c:
# t:
# c:
# t:
# c:#{'decisão'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:tipoMinuta')) ? 'Registrar conclusão para decisão' : 'Triagem'}
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') or not tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')}
# t:Condição 128
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')}
# t:Condição 129
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') or not tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')}
# t:Condição 130
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')}
# t:Condição 121
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:remessaCancelada') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:remessaCancelada')) ? 'Testar retorno processo sem julgamento' : 'Analisar retorno da instância superior'}
# t:
# c:
# t:
# c:#{(not ((not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')) or (not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')))) ? 'Triagem' : 'Analisar existência de recursos'}
# t:Condição 139
# c:
# t:
# c:#{((not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')) or (not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')))}
# t:Condição 140
# c:#{((not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')) or (not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')))}
# t:Condição 140
# c:#{(not (not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')) or (not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')))}
# t:Condição 141
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{('AER'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:retornoED')) ? 'AER' : ('CDP'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:retornoED')) ? 'CDP' : ('ATJ'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:retornoED')) ? 'ATJ' : 'Triagem')))}
# t:Condição 136
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(processoTrfHome.instance.classeJudicial.codClasseJudicial == '12137') ? 'Avalia existência decisão incidental' : 'Testa classe incidental'}
# t:Condição 67
# c:
# t:
# c:
# t:
# c:#{(processoTrfHome.getInstance().isIncidental() and processoTrfHome.instance.classeJudicial.codClasseJudicial != '232') ? 'Testa variavel decisão' : 'Testa variavel julgamento'}
# t:Condição 68
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') ? 'Testa variavel julgamento' : 'Avalia existência decisão incidental'}
# t:Condição 69
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') ? 'Término' : 'Avalia existência de julgamento'}
# t:Condição 70
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{'despachoInicial'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:tipoMinuta')) ? 'Minutar despacho (inicial)': 'Testa minutar decisão (inicial)'}
# t:Condição 71
# c:
# t:
# c:#{'decisãoInicial'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:tipoMinuta')) ? 'Minutar decisão (inicial)': 'Testa minutar sentença (inicial)'}
# t:Condição 72
# c:
# t:
# c:#{'sentençaInicial'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:tipoMinuta')) ? 'Minutar sentença (inicial)': 'Testa minutar decisão de tutela de urgência'}
# t:Condição 73
# c:
# t:
# c:#{'decisãoTutelaUrgência'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:tipoMinuta')) ? 'Minutar decisão de tutela de urgência': 'Testa minutar despacho'}
# t:Condição 74
# c:
# t:
# c:#{'despacho'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:tipoMinuta')) ? 'Minutar despacho': 'Testa minutar decisão'}
# t:Condição 75
# c:
# t:
# c:#{'decisão'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:tipoMinuta')) ? 'Minutar decisão': 'Testa minutar sentença'}
# t:Condição 76
# c:
# t:
# c:#{'sentença'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:tipoMinuta')) ? 'Minutar sentença': 'Término'}
# t:Condição 77
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEPAJAtoOrdPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 78
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEPAJAtoOrdPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 78
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEPAJAtoOrdPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 78
# c:
# t:
# c:
# t:
# c:#{'sim'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 79
# c:#{'sim'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 79
# c:#{'sim'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 79
# c:#{'não'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 80
# c:#{'não'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 80
# c:#{'não'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 80
# c:#{'não'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 80
# c:#{(pjeFluxoTJPEPAJAtoOrdPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 78
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEPAJAtoOrdPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 78
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEPAJAtoOrdPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 78
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEPAJAtoOrdPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 78
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{'sim'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 79
# c:#{'sim'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 79
# c:#{'sim'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 79
# c:
# t:
# c:#{'não'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 80
# c:#{'não'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 80
# c:#{'não'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:minutaInicial'))}
# t:Condição 80
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:urgencia') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:urgencia') ? 'Cumprir determinações (urgência)' : 'Cumprir determinações'}
# t:Condição 81
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:
# t:
# c:
# t:
# c:#{(atoComunicacaoService.getAtosComunicacaoAbertos(processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo'))) > 0)}
# t:Condição 29
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:
# t:
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:
# t:
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:#{not (idsOrgaosJulgadoresPRATCARTREV.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 83
# c:#{(idsOrgaosJulgadoresPRATCARTREV.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 84
# c:
# t:
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:
# t:
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigem') or (processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador == tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigem'))}
# t:Condição 85
# c:#{(1==2) and (not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 86
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigem') or (processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador == tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigem'))) and ((not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']'))))}
# t:Condição 87
# c:#{not (empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigem') or (processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador == tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigem')))}
# t:Condição 88
# c:
# t:
# c:#{('[1338][1469][5532][5545][5546][5186][5534][5197][5533]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 89
# c:#{(processoParteExpedienteManager.recuperaExpedientesAbertosPorMeiosComunicacaoAndProcessoTrf(null, processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo'))).size > 0) and !('[5186][5366][5534]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 2
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:
# t:
# c:
# t:
# c:#{(atoComunicacaoService.getAtosComunicacaoAbertos(processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo'))) > 0)}
# t:Condição 29
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:
# t:
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:
# t:
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:#{not (idsOrgaosJulgadoresPRATCARTREV.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 83
# c:#{(idsOrgaosJulgadoresPRATCARTREV.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 84
# c:
# t:
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:#{(not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 82
# c:
# t:
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigem') or (processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador == tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigem'))}
# t:Condição 85
# c:#{(1==2) and (not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 86
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigem') or (processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador == tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigem'))) and ((not idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']'))))}
# t:Condição 87
# c:#{not (empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigem') or (processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador == tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigem')))}
# t:Condição 88
# c:
# t:
# c:#{('[1338][1469][5532][5545][5546][5186][5534][5197][5533]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 89
# c:#{(processoParteExpedienteManager.recuperaExpedientesAbertosPorMeiosComunicacaoAndProcessoTrf(null, processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo'))).size > 0) and !('[5186][5366][5534]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 2
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{"total".equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:bloqueio')) ? 'Verificar urgência' : 'Término'}
# t:Condição 90
# c:
# t:
# c:
# t:
# c:#{'recusada'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:liberacao')) ? 'Criar variável de conclusão para decisão' : 'Verificar urgência'}
# t:Condição 91
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal') or (''.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal')))}
# t:Condição 31
# c:
# t:
# c:
# t:
# c:#{(empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal') or (''.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal')))) ? 'Juntada vazia' : 'Juntada não vazia'}
# t:Condição 32
# c:
# t:
# c:#{not (pjeFluxoTJPEJurisdicoesNaoEnviamContadoria.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']')))}
# t:Condição 92
# c:#{not (pjeFluxoTJPEJurisdicoesNaoEnviamAP.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']')))}
# t:Condição 93
# c:#{not (pjeFluxoTJPEJurisdicoesNaoEnviamPartidor.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']')))}
# t:Condição 94
# c:#{(processoTrfHome.getInstance().getJurisdicao().getJurisdicao().equals('Recife - Varas')) and (pjeFluxoTJPECompetenciasFamilia.contains((('[').concat(processoTrfHome.getInstance().getCompetencia().getIdCompetencia())).concat(']')))}
# t:Condição 95
# c:#{(pjeFluxoTJPEJurisdicoesDS.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']')))}
# t:Condição 96
# c:#{(pjeFluxoTJPEOrgaosEquipeMD01.contains((('[').concat(processoTrfHome.getInstance().getOrgaoJulgador().getIdOrgaoJulgador())).concat(']'))) or (pjeFluxoTJPEOrgaosEquipeMD02.contains((('[').concat(processoTrfHome.getInstance().getOrgaoJulgador().getIdOrgaoJulgador())).concat(']'))) or (pjeFluxoTJPEOrgaosEquipeMD03.contains((('[').concat(processoTrfHome.getInstance().getOrgaoJulgador().getIdOrgaoJulgador())).concat(']')))}
# t:Condição 97
# c:#{pjeFluxoTJPEIDsOrgaosNIJ.contains((('[').concat(processoTrfHome.getInstance().getOrgaoJulgador().getIdOrgaoJulgador())).concat(']'))}
# t:Condição 98
# c:#{(processoTrfHome.getInstance().getJurisdicao().getJurisdicao().equals('Recife - Varas')) and (pjeFluxoTJPEIDsOrgaosNIJ.contains((('[').concat(processoTrfHome.getInstance().getOrgaoJulgador().getIdOrgaoJulgador())).concat(']')))}
# t:Condição 99
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(processoTrfHome.getInstance().getJurisdicao().getJurisdicao().equals('Recife - Varas')) and (pjeFluxoTJPECompetenciasFamilia.contains((('[').concat(processoTrfHome.getInstance().getCompetencia().getIdCompetencia())).concat(']')))}
# t:Condição 95
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not (pjeFluxoTJPEJurisdicoesNaoEnviamContadoria.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']')))}
# t:Condição 92
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{'recusada'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:rpf:liberacao')) ? 'Decidir em finalização' : 'Verificar pendências finais'}
# t:Condição 100
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not (pjeFluxoTJPEJurisdicoesNaoEnviamContadoria.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']')))}
# t:Condição 92
# c:
# t:
# c:#{not (pjeFluxoTJPEJurisdicoesNaoEnviamContadoria.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']')))}
# t:Condição 92
# c:
# t:
# c:#{not (pjeFluxoTJPEJurisdicoesNaoEnviamContadoria.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']')))}
# t:Condição 92
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:processo:jec') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:processo:jec') ? 'Conferência inicial (Processo antigo JEC)' : 'Avalia processo com segredo de justiça'}
# t:Condição 101
# c:
# t:
# c:#{(pjeFluxoTJPEidsCompetenciasSegredoJustica.contains((('[').concat(tramitacaoProcessualService.recuperaProcesso().competencia.idCompetencia.toString())).concat(']'))) ? 'Marcar processo como segredo de justica' : 'Avaliar se órgão é central'}
# t:Condição 102
# c:
# t:
# c:
# t:
# c:#{(idOrgaoCentrais.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']'))) ? 'Testa se superou fase inicial' : 'Verificar processo plantão judiciário'}
# t:Condição 103
# c:
# t:
# c:#{(pjeFluxoTJPEidsJurisdicoesPlantao.contains((('[').concat(processoTrfHome.instance.jurisdicao.idJurisdicao.toString())).concat(']'))) ? 'Registrar movimentação de plantão judiciário' : 'Registrar conclusão (decisão)'}
# t:Condição 104
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEidsJurisdicoesPagamento.contains((('[').concat(processoTrfHome.instance.jurisdicao.idJurisdicao.toString())).concat(']'))) and (not pjeFluxoTJPEidsCompetenciasSemPagamento.contains((('[').concat(tramitacaoProcessualService.recuperaProcesso().competencia.idCompetencia.toString())).concat(']'))) ? 'Verificar justica gratuita' : 'Verificar urgência (inicial)'}
# t:Condição 105
# c:
# t:
# c:#{tramitacaoProcessualService.recuperaProcesso().getJusticaGratuita() ? 'Verificar urgência (posGratuita)' : 'Verificar Redistribuicao'}
# t:Condição 106
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuido') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuido') ? 'Verificar urgência (inicial)' : 'Aguardando pagamento'}
# t:Condição 107
# c:
# t:
# c:
# t:
# c:#{tramitacaoProcessualService.sigiloso() or tramitacaoProcessualService.temUrgencia() or (pjeFluxoTJPEidsCompetenciasComUrgencia.contains((('[').concat(tramitacaoProcessualService.recuperaProcesso().competencia.idCompetencia.toString())).concat(']'))) or tramitacaoProcessualService.recuperaVariavel('pje:fluxo:processoPlantao') ? 'Conferência inicial (urgência)' : 'Conferência inicial'}
# t:Condição 108
# c:
# t:
# c:#{tramitacaoProcessualService.sigiloso() or tramitacaoProcessualService.temUrgencia() or (pjeFluxoTJPEidsCompetenciasComUrgencia.contains((('[').concat(tramitacaoProcessualService.recuperaProcesso().competencia.idCompetencia.toString())).concat(']'))) or tramitacaoProcessualService.recuperaVariavel('pje:fluxo:processoPlantao') ? 'Conferência inicial (urgência)' : 'Conferência inicial (justiça gratuita)'}
# t:Condição 109
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{('[1338][1469][5532][5545][5546][5186][5534][5197][5533]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 89
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:jurisdicaoPagamento') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:jurisdicaoPagamento')}
# t:Condição 110
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{('[1338][1469][5532][5545][5546][5186][5534][5197][5533]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 89
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{('[1338][1469][5532][5545][5546][5186][5534][5197][5533]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 89
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:jurisdicaoPagamento') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:jurisdicaoPagamento')}
# t:Condição 110
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{('CI'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:retornoVMP')))}
# t:Condição 111
# c:#{('CM'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:retornoVMP')))}
# t:Condição 112
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuido') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuido') ? 'Avalia processo com segredo de justiça' : 'Testa julgamento'}
# t:Condição 113
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')? 'Intimar de julgamento' : 'Testa remessa PAJ'}
# t:Condição 114
# c:
# t:
# c:#{tramitacaoProcessualService.temSituacao('jus:tjpe:fluxo:remessaPAJ') ? 'Remeter PAJ' : 'Testa se superou fase inicial'}
# t:Condição 115
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:bvc:curso') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:bvc:curso') ? 'Triagem de processo em curso' : 'Triagem de resultado inicial'}
# t:Condição 116
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') or not(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao'))}
# t:Condição 117
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{('[1]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 118
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{agrupamentoClasseJudicialManager.pertence(tramitacaoProcessualService.recuperaProcesso().classeJudicial, 'APC')}
# t:Condição 119
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')) or (not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao'))}
# t:Condição 120
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')}
# t:Condição 121
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and processoTrfHome.instance.classeJudicial.codClasseJudicial == '12137'}
# t:Condição 122
# c:#{(pjeFluxoTJPEInsSupProMatPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 123
# c:#{(pjeFluxoTJPEInsSupSemJulPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']'))) and not ((not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')) or (not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')))}
# t:Condição 124
# c:#{(pjeFluxoTJPEArqDefPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 125
# c:#{(pjeFluxoTJPEFACFRPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 126
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') or not(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao'))}
# t:Condição 117
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{('[1]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 118
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{agrupamentoClasseJudicialManager.pertence(tramitacaoProcessualService.recuperaProcesso().classeJudicial, 'APC')}
# t:Condição 119
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')) or (not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao'))}
# t:Condição 120
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')}
# t:Condição 121
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1)}
# t:Condição 1
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and processoTrfHome.instance.classeJudicial.codClasseJudicial == '12137'}
# t:Condição 122
# c:#{(pjeFluxoTJPEInsSupProMatPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 123
# c:#{(pjeFluxoTJPEInsSupSemJulPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']'))) and not ((not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')) or (not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')))}
# t:Condição 124
# c:#{(pjeFluxoTJPEArqDefPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 125
# c:#{(pjeFluxoTJPEFACFRPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 126
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuiçãoCancelada') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuiçãoCancelada') ? 'Cancelada' : 'Continuar'}
# t:Condição 127
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') or not tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')}
# t:Condição 128
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')}
# t:Condição 129
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') or not tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')}
# t:Condição 130
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')}
# t:Condição 121
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:identificador:orgaoOrigemCCMA') ? 'Devolver para o orgão de origem' : 'Testa se superou fase inicial'}
# t:Condição 131
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1469) and not empty processoHome.getUltimoProcessoEvento(processoTrfHome.instance.processo, 'Julgamento') and ((not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and not tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')))}
# t:Condição 132
# c:#{(usuarioLogadoLocalizacaoAtual.papel.getIdPapel()==1469) and ((not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')))}
# t:Condição 133
# c:#{('[1338][1469][5532][5545][5546][5186][5534][5197][5533]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 89
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{'decisão'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:paj20:tipoMinuta')) ? 'Registrar conclusão para decisão' : 'Testa redistribuição'}
# t:Condição 134
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuido') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuido') ? 'Avalia processo com segredo de justiça' : 'Testa remessa PAJ'}
# t:Condição 135
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{('AER'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:retornoED')) ? 'AER' : ('CDP'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:retornoED')) ? 'CDP' : ('ATJ'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:retornoED')) ? 'ATJ' : 'Triagem')))}
# t:Condição 136
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{idsJurisdiçõesRemessa.contains((('[').concat(processoTrfHome.instance.jurisdicao.idJurisdicao.toString())).concat(']')) and (not agrupamentoClasseJudicialManager.pertence(tramitacaoProcessualService.recuperaProcesso().classeJudicial, 'NRI')) ? 'Subprocesso Remeter para instância superior' : 'Encaminhar para instância superior'}
# t:Condição 137
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:remessaCancelada') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:remessaCancelada')) ? 'Testa retorno processo sem julgamento' : 'Analisar retorno da instância superior'}
# t:Condição 138
# c:
# t:
# c:#{(not ((not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')) or (not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')))) ? 'Triagem' : 'Analisar existência de recursos'}
# t:Condição 139
# c:
# t:
# ...
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{atoComunicacaoService.getAtosComunicacaoAbertos(processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo'))) > 0 ? 'Analisar manifestação' : 'Término'}
# t:Condição 384
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{atoComunicacaoService.getAtosComunicacaoAbertos(processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo'))) > 0 ? 'Processo com prazo em curso' : 'Término'}
# t:Condição 27
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:AtoJaAssinado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:AtoJaAssinado')}
# t:Condição 172
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:AtoJaAssinado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:AtoJaAssinado')}
# t:Condição 172
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:AtoJaAssinado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:AtoJaAssinado')}
# t:Condição 172
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:AtoJaAssinado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:AtoJaAssinado')}
# t:Condição 172
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:AtoJaAssinado') or not tramitacaoProcessualService.recuperaVariavel('pje:fluxo:AtoJaAssinado')}
# t:Condição 173
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:ordenadoBloqueio') ? 'Lançar movimentação de bloqueio' : 'Término'}
# t:Condição 385
# c:
# t:
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:tipoApreciacaoInicial') == 1 ? 'Minutar deferimento da inicial': 'Testa extinção'}
# t:Condição 386
# c:
# t:
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:tipoApreciacaoInicial') == 2 ? 'Minutar sentença de extinção' : 'Testa reunião'}
# t:Condição 387
# c:
# t:
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:tipoApreciacaoInicial') == 3 ? 'Minutar reunião de processos' : 'Minutar decisões iniciais diversas'}
# t:Condição 388
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEPAJAtoOrdPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 78
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{'despacho'.equals(tramitacaoProcessualService.recuperaVariavel('pje:tipoConclusao')) ? 'Minutar despacho' : ('decisao'.equals(tramitacaoProcessualService.recuperaVariavel('pje:tipoConclusao')) ? 'Minutar decisão' : 'Testa existência suspensão')}
# t:Condição 389
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{'suspensao'.equals(tramitacaoProcessualService.recuperaVariavel('pje:tipoConclusao')) ? 'Minutar decisão de suspensão' : 'Minutar sentença'}
# t:Condição 390
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEPAJAtoOrdPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 78
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEPAJAtoOrdPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 78
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEPAJAtoOrdPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 78
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(pjeFluxoTJPEPAJAtoOrdPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 78
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesEletronico().size() > 0 ? 'Encaminhar Via Sistema' : 'JoinComunicacao'}
# t:Condição 20
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesDiario().size() > 0 ? 'Publicar DJE' : 'JoinComunicacao'}
# t:Condição 21
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesMandados().size() > 0 ? 'Encaminhar Mandado' : 'JoinComunicacao'}
# t:Condição 22
# c:#{processoExpedienteHome.buscaCentralMandado().size()>0}
# t:Condição 23
# c:#{processoExpedienteHome.buscaCentralMandado().size()<=0}
# t:Condição 24
# c:
# t:
# c:#{processoExpedienteHome.buscaCentralMandado().size()>1 ? 'Selecionar Central de Mandado' : 'Gerar movimentação mandado'}
# t:Condição 143
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesCorreios().size() > 0 ? 'Imprimir Correspondência' : 'JoinComunicacao'}
# t:Condição 25
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesPrecatorias().size() > 0 ? 'Encaminhar Carta' : 'JoinComunicacao'}
# t:Condição 26
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(atoComunicacaoService.getAtosComunicacaoAbertos(processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo'))) > 0)}
# t:Condição 29
# c:#{not (idsOrgaosJulgadoresPRATCARTREV.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 83
# c:#{(idsOrgaosJulgadoresPRATCARTREV.contains((('[').concat(processoTrfHome.instance.orgaoJulgador.idOrgaoJulgador.toString())).concat(']')))}
# t:Condição 84
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{('[1338][1469][5532][5545][5546][5186][5534][5197][5533]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 89
# c:
# t:
# c:
# t:
# c:#{(processoParteExpedienteManager.recuperaExpedientesAbertosPorMeiosComunicacaoAndProcessoTrf(null, processoJudicialService.findById(tramitacaoProcessualService.recuperaVariavel('processo'))).size > 0) and !('[5186][5366][5534]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 2
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{"total".equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:bloqueio')) ? 'Cumprir determinações' : 'Término'}
# t:Condição 391
# c:
# t:
# c:
# t:
# c:#{'recusada'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:liberacao')) ? 'Criar variável de conclusão para decisão' : 'Cumprir determinações'}
# t:Condição 392
# c:
# t:
# c:
# t:
# c:#{not (pjeFluxoTJPEJurisdicoesNaoEnviamContadoria.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']')))}
# t:Condição 92
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal') or (''.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal')))}
# t:Condição 31
# c:
# t:
# c:
# t:
# c:#{(empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal') or (''.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:digitalizacao:documentoPrincipal')))) ? 'Juntada vazia' : 'Juntada não vazia'}
# t:Condição 32
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{true == tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:ordenadaAudiencia') ? 'Designar audiência' : 'Testa envio automático de citação'}
# t:Condição 393
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:ordenadaIntimacaoAutomatica') ? 'Prepara ato de intimação do exequente': 'Testa ordem de designação de audiência' }
# t:Condição 394
# c:
# t:
# c:#{true == tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:ordenadaCitacaoAutomatica') ? 'Prepara ato de citação dos réus' : 'Cumprir demais determinações'}
# t:Condição 395
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:ordenadoBloqueio') ? 'Realizar bloqueio de ativos financeiros' : 'Junção em cumprimento de decisão em execução'}
# t:Condição 396
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not (pjeFluxoTJPEJurisdicoesNaoEnviamContadoria.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']')))}
# t:Condição 92
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{'recusada'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:liberacao')) ? 'Decidir em finalização de execução' : 'Verificar pendência em execução fiscal'}
# t:Condição 397
# c:#{not (pjeFluxoTJPEJurisdicoesNaoEnviamContadoria.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getIdJurisdicao())).concat(']')))}
# t:Condição 92
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{('[1338][1469][5532][5545][5546][5186][5534][5197][5533]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 89
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuido') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuido') ? 'Triagem de resultado inicial' : 'Testa julgamento'}
# t:Condição 398
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')? 'Testa intimados de julgamento' : 'Testa determinação de suspensão do art. 40'}
# t:Condição 399
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{agrupamentoClasseJudicialManager.pertence(tramitacaoProcessualService.recuperaProcesso().classeJudicial, 'APC')}
# t:Condição 119
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')}
# t:Condição 129
# c:
# t:
# c:#{('[1]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 118
# c:#{(pjeFluxoTJPEInsSupProMatPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 123
# c:#{(pjeFluxoTJPEInsSupSemJulPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']'))) and not ((not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')) or (not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')))}
# t:Condição 124
# c:#{(pjeFluxoTJPEArqDefPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 125
# c:#{(pjeFluxoTJPEFACFRPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 126
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:suspensao:ef40') ? 'Suspensão do artigo 40 da LEF' : 'Testa suspensão por parcelamento'}
# t:Condição 400
# c:
# t:
# c:
# t:
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:suspensao:parcelamento') ? 'Suspenso por parcelamento' : 'Testa determinação de arquivamento'}
# t:Condição 401
# c:
# t:
# c:
# t:
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:arquivadoProvisoriamente') ? 'Arquivado provisoriamente' : (tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:curso') ? 'Triagem de processo em curso' : 'Triagem de resultado inicial')}
# t:Condição 402
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{agrupamentoClasseJudicialManager.pertence(tramitacaoProcessualService.recuperaProcesso().classeJudicial, 'APC')}
# t:Condição 119
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')}
# t:Condição 129
# c:#{('[1]'.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 118
# c:#{(pjeFluxoTJPEInsSupProMatPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 123
# c:#{(pjeFluxoTJPEInsSupSemJulPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']'))) and not ((not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')) or (not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:decisao')))}
# t:Condição 124
# c:#{(pjeFluxoTJPEArqDefPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 125
# c:#{(pjeFluxoTJPEFACFRPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# t:Condição 126
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuiçãoCancelada') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:redistribuiçãoCancelada') ? 'Cancelada' : 'Continuar'}
# t:Condição 127
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{'decisao'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:conclusao')) ? 'Registrar conclusão para decisão' : 'Triagem'}
# t:Condição 403
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{'todos'.equals(tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:julgamento:intimados')) ? 'Analisar existência de recursos' : 'Intimar de julgamento'}
# t:Condição 404
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{(not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:remessaCancelada') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:remessaCancelada')) ? 'Analisar existência de recursos' : 'Analisar retorno da instância superior'}
# t:Condição 405
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:curso') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:ef:curso') ? 'Triagem de processo em curso' : 'Triagem de resultado inicial'}
# t:Condição 406
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{not empty tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado') and tramitacaoProcessualService.recuperaVariavel('pje:fluxo:julgado')? 'Intimar de julgamento' : 'Cumprir decisão em incidente'}
# t:Condição 407
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesEletronico().size() > 0 ? 'Encaminhar Via Sistema' : 'JoinComunicacao'}
# t:Condição 20
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesDiario().size() > 0 ? 'Publicar DJE' : 'JoinComunicacao'}
# t:Condição 21
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesMandados().size() > 0 ? 'Encaminhar Mandado' : 'JoinComunicacao'}
# t:Condição 22
# c:
# t:
# c:
# t:
# c:
# t:
# c:#{conectorMandados.haVariasCentraisMandado() ? 'Selecionar Central de Mandado' : 'Encaminhar Central Mandados'}
# t:
# c:
# t:
# c:
# t:
# c:#{tramitacaoProcessualService.recuperaVariavel('pje:fluxo:centralEscolhida') == null ? 'Selecionar Central de Mandado' : 'Encaminhar Central Mandados'}
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesCorreios().size() > 0 ? 'Imprimir Correspondência' : 'JoinComunicacao'}
# t:Condição 25
# c:
# t:
# c:
# t:
# c:#{comunicacaoProcessualAction.getExpedientesPrecatorias().size() > 0 ? 'Encaminhar Carta' : 'JoinComunicacao'}
# t:Condição 26
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:
# c:
# t:

# %%
df['Condicao']
# df_traducao[df_traducao['DE']=="#{pjeFluxoTJPEIDsOrgaosNIJEIJABOATAO.contains((('[').concat(processoTrfHome.getInstance().getOrgaoJulgador().getIdOrgaoJulgador())).concat(']'))}"]

# %%
df.to_csv('../dados/df_1_grau.csv', index = False, encoding='utf-8')

# %%
df.sample(20)
# Out:
#                                                  Processo  \
# 453                             Juizados Especiais Cíveis
# 1176                           Fluxo básico em vara cível
# 263                      Fluxo de Cumprimento de Sentença
# 2482                                Preparar ato judicial
# 2434         Apreciação de recebimento de execução fiscal
# 2203                        Fluxo equipe multidisciplinar
# 2282  Fluxo remeter para o núcleo da infância e juventude
# 603                              Fluxo básico de migração
# 408                             Juizados Especiais Cíveis
# 2751                                      Execução fiscal
# 1123                           Fluxo básico em vara cível
# 1051                         Realizar providências finais
# 834                        Preparar ato judicial (Padrão)
# 157                                  Embargos de Terceiro
# 1390                             Remeter para outro órgão
# 1516                  Fluxo perícia da diretoria de saúde
# 60                                  Controle de Audiência
# 1821                Fluxo remeter para apoio psicossocial
# 1850                Fluxo remeter para apoio psicossocial
# 2338                    Preparar vários atos - Secretaria
#
#                                                                              No origem  \
# 453                                                                  Ato de Secretaria
# 1176                                                  Triagem de processo em curso [B]
# 263                                                                   .Verificar Prazo
# 2482                                                                  Minutar despacho
# 2434                                                      Minutar reunião de processos
# 2203                                                         Testa juntada vazia [EMD]
# 2282  Gerar movimentação envio Equipe Psicossocial de Cabo Santo Agostinho VR [REMNIJ]
# 603                                                  Apensar processos (migração) [MB]
# 408                                                         Designar Audiência Inicial
# 2751                                                      Triagem de processo em curso
# 1123                                              Cancelar deslocamento de fluxo 1 [B]
# 1051                                                                Testa recusa [RPF]
# 834                 Apagar ato ordinatório em elaboracao e enviar para sentença [PAJP]
# 157                                             Finalizar Preparar Ato Judicial [EMBT]
# 1390                   Definir CEJUSC-Cabo de Santo Agostinho como orgão destino [REM]
# 1516                                                            Preparar juntada [PDS]
# 60                                                                      Tarefa inicial
# 1821                                         Testa apoio psicossocial Floresta [REMAP]
# 1850                                         Testa apoio psicossocial Paulista [REMAP]
# 2338                                          Preparar ato - Secretaria assinar [PVAS]
#
#              Tipo  \
# 453     task-node
# 1176    task-node
# 263     task-node
# 2482    task-node
# 2434    task-node
# 2203     decision
# 2282         node
# 603     task-node
# 408     task-node
# 2751    task-node
# 1123         node
# 1051     decision
# 834          node
# 157     task-node
# 1390         node
# 1516    task-node
# 60    start-state
# 1821     decision
# 1850     decision
# 2338    task-node
#
#                                                         Transicao  \
# 453                                          Remeter internamente
# 1176  Encaminhar para instância superior (processo materializado)
# 263                                               Bloqueio Online
# 2482                                  Tornar decisão de suspensão
# 2434                       Enviar ao magistrado (assinar em lote)
# 2203                                            Juntada não vazia
# 2282                      Núcleo da infância e juventude [REMNIJ]
# 603                                            Triagem (migração)
# 408                                                   Aguardar AR
# 2751                                       Conclusão para decisão
# 1123                             Testa redistribuição inicial [B]
# 1051                                  Verificar pendências finais
# 834                                       Minutar sentença [PAJP]
# 157              Enviar para o novo fluxo de embargos de terceiro
# 1390                 Confirmar o envio para o órgão destino [REM]
# 1516                                    Encaminhar para avaliação
# 60                                          Controle de Audiência
# 1821                           Testa apoio psicossocial Garanhuns
# 1850                                                     Paulista
# 2338                                   Cancelar ato em elaboração
#
#                                                                 No destino  \
# 453                                             Remeter internamente [JEC]
# 1176                            Aguardar retorno de instância superior [B]
# 263                                                       .Bloqueio Online
# 2482                                          Minutar decisão de suspensão
# 2434                               Confirmar - reunião de processos (lote)
# 2203                                                 Avaliar juntada [EMD]
# 2282                               Núcleo da infância e juventude [REMNIJ]
# 603                                                Triagem (migração) [MB]
# 408                                                            Aguardar AR
# 2751                                      Registrar conclusão para decisão
# 1123                                      Testa redistribuição inicial [B]
# 1051                                     Verificar pendências finais [RPF]
# 834                                                Minutar sentença [PAJP]
# 157                       Enviar para o novo fluxo de embargos de terceiro
# 1390                          Confirmar o envio para o órgão destino [REM]
# 1516                                                 Avaliar juntada [PDS]
# 60                                                   Controle de Audiência
# 1821                            Testa apoio psicossocial Garanhuns [REMAP]
# 1850  Gerar movimentação envio perícia apoio psicossocial Paulista [REMAP]
# 2338                                   Remover minuta não elaborada [PVAS]
#
#      Sub-process              Raia  \
# 453                   Conhecimento
# 1176                    Secretaria
# 263                    .Secretaria
# 2482                    Assessoria
# 2434                    Assessoria
# 2203
# 2282
# 603                       Migração
# 408                         Malote
# 2751                 Secretaria N2
# 1123
# 1051
# 834
# 157                   ..Magistrado
# 1390
# 1516              Secretaria-Apoio
# 60
# 1821
# 1850
# 2338                    Secretaria
#
#                                                                                                                                                                                            Condicao  \
# 453
# 1176                                                          #{(pjeFluxoTJPEInsSupProMatPapeis.contains((('[').concat(usuarioLogadoLocalizacaoAtual.papel.getIdPapel().toString())).concat(']')))}
# 263
# 2482
# 2434
# 2203
# 2282
# 603
# 408
# 2751
# 1123
# 1051
# 834
# 157
# 1390
# 1516
# 60
# 1821
# 1850  #{(pjeFluxoTJPEJurisdicoesAPPaulista.contains((('[').concat(processoTrfHome.getInstance().getJurisdicao().getJurisdicao())).concat(']'))) ? 'Paulista': 'Testa apoio psicossocial Pesqueira'}
# 2338
#
#      CondicaoTratada
# 453
# 1176    Condição 123
# 263
# 2482
# 2434
# 2203
# 2282
# 603
# 408
# 2751
# 1123
# 1051
# 834
# 157
# 1390
# 1516
# 60
# 1821
# 1850    Condição 275
# 2338

# %%
dfr.sample(100)

# %%
dfta

# %%
df_locpap.sample(100)

# %%
df[df['Condicao']!=''].to_csv()

# %%
g = criaGraphoFluxo(df)
# Out:
# Fluxo arquivo de juizados
# Definir tipo de arquivo definitivo [AJ]
# Fluxo arquivo de varas
# Definir tipo de arquivo definitivo [AV]
# Preparar ato judicial (Padrão)
# Testa minutar despacho (inicial) [PAJP]
# JECPAJ1 - Preparar ato judicial - 1
# É Minuta Despacho Inicial?
# Controle de Audiência
# Controle de Audiência
# Remeter para instância superior
# Remeter para instância superior
# JECPAC1 - Preparar ato de comunicação - 1
# Preparar comunicação [JECPAC1]
# Preparar ato ordinatório
# Preparar ato ordinatório
# Preparar ato judicial (Padrão)
# Testa minutar despacho (inicial) [PAJP]
# JECPAJ1 - Preparar ato judicial - 1
# É Minuta Despacho Inicial?
# JECPAJ1 - Preparar ato judicial - 1
# É Minuta Despacho Inicial?
# Remeter para instância superior
# Remeter para instância superior
# JECPAC1 - Preparar ato de comunicação - 1
# Preparar comunicação [JECPAC1]
# Controle de Audiência
# Controle de Audiência
# Preparar ato ordinatório
# Preparar ato ordinatório
# JECPAJ1 - Preparar ato judicial - 1
# É Minuta Despacho Inicial?
# JECPAJ1 - Preparar ato judicial - 1
# É Minuta Despacho Inicial?
# JEC_PAC_CI - Citar (Inicial)
# Citar (Inicial) [JEC_PAC_CI]
# Controle de Audiência
# Controle de Audiência
# Fluxo alteração de classe e fluxo com redistribuição
# Inicializar variaveis [FACFR]
# Preparar vários atos - Magistrado
# Testa fluxo novo [PVAM]
# Preparar vários atos - Secretaria
# Testa fluxo novo [PVAS]
# Fluxo de bloqueio de ativos do devedor
# Preparar ordem de bloqueio
# Fluxo de liberação de ativos do devedor
# Preparar ordem de liberação
# Preparar ato judicial (Padrão)
# Testa minutar despacho (inicial) [PAJP]
# Preparar ato ordinatório
# Preparar ato ordinatório
# Remeter para instância superior
# Remeter para instância superior
# Fluxo arquivo geral
# Gerar movimentação processo arquivado [AG]
# Preparar ato de cartório
# Inicializar variaveis [PRATCART]
# JECPAC1 - Preparar ato de comunicação - 1
# Preparar comunicação [JECPAC1]
# Deslocamento de processo para outro órgão
# Selecionar o órgão destino [DPO]
# Fluxo remeter para contadoria
# Testa contadoria Recife 01 [REMCONT]
# Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# Controle de prazos
# Testa existência de expedientes
# Preparar ato judicial (Padrão)
# Testa minutar despacho (inicial) [PAJP]
# Preparar ato judicial (Padrão)
# Testa minutar despacho (inicial) [PAJP]
# Cumprimento de decisão
# Verificar urgência [CD]
# Preparar comunicação com controle de prazo
# Criar comunicação
# Preparar ato judicial em recurso
# Minutar decisão em recurso
# Remeter para instância superior
# Remeter para instância superior
# Realizar providências finais
# Verificar pendências finais [RPF]
# Preparar ato de cartório
# Inicializar variaveis [PRATCART]
# Deslocamento de processo para outro órgão
# Selecionar o órgão destino [DPO]
# Fluxo arquivo geral
# Gerar movimentação processo arquivado [AG]
# Avaliar decisão proferida
# Testa classe req.apreensao de veiculo [ADP]
# Controle de Perícia
# Analisar perícia [CP]
# Preparar ato de cartório
# Inicializar variaveis [PRATCART]
# Preparar ato de cartório com revisor
# Inicializar variaveis [PRATCARTREV]
# Preparar vários atos - Magistrado
# Testa fluxo novo [PVAM]
# Preparar vários atos - Secretaria
# Testa fluxo novo [PVAS]
# Remessa externa temporária
# Analisar remessa [RET]
# Fluxo de bloqueio de ativos do devedor
# Preparar ordem de bloqueio
# Fluxo de liberação de ativos do devedor
# Preparar ordem de liberação
# Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# Controle de prazos
# Testa existência de expedientes
# Avaliação de bens
# Expedir mandado de avaliação
# Preparar ato ordinatório
# Preparar ato ordinatório
# Remeter para outro órgão
# Selecionar o órgão destino [REM]
# Devolver para o órgão de origem
# Confirmar a devolução para o órgão de origem [DEV]
# Fluxo remeter para contadoria
# Testa contadoria Recife 01 [REMCONT]
# Fluxo remeter para apoio psicossocial
# Testa apoio psicossocial Recife [REMAP]
# Fluxo remeter para setor de partilha
# Testa setor de partilha Abreu e Lima [REMPART]
# Fluxo partilha
# Analisar processo [PAR]
# Fluxo cálculo da contadoria
# Analisar processo [CONT]
# Fluxo conciliação do juizado informal de família
# Cancelar possivel deslocamento de fluxo [CJIF]
# Fluxo remeter para equipe multidisciplinar
# Testa equipe multidisciplinar 01 [REMEMD]
# Fluxo remeter para o núcleo da infância e juventude
# Definir núcleo da infância e juventude [REMNIJ]
# Fluxo justiça restaurativa
# Cancelar possivel deslocamento de fluxo [JR]
# Preparar ato de comunicação - JIF
# Preparar comunicação [JIF]
# Fluxo perícia apoio psicossocial
# Analisar processo [PAP]
# Fluxo perícia da diretoria de saúde
# Gerar movimentação envio diretoria de saúde [PDS]
# Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# Preparar ato de cartório
# Inicializar variaveis [PRATCART]
# Fluxo de bloqueio de ativos do devedor
# Preparar ordem de bloqueio
# Fluxo de liberação de ativos do devedor
# Preparar ordem de liberação
# Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# Controle de prazos
# Testa existência de expedientes
# Avaliação de bens
# Expedir mandado de avaliação
# Preparar comunicação com controle de prazo
# Criar comunicação
# Preparar comunicação com controle de prazo
# Criar comunicação
# Preparar ato judicial (Padrão)
# Testa minutar despacho (inicial) [PAJP]
# Preparar ato judicial (Padrão)
# Testa minutar despacho (inicial) [PAJP]
# Fluxo de liberação de ativos do devedor
# Preparar ordem de liberação
# Fluxo de liberação de ativos do devedor
# Preparar ordem de liberação
# Fluxo remeter para contadoria
# Testa contadoria Recife 01 [REMCONT]
# Preparar ato judicial (Padrão)
# Testa minutar despacho (inicial) [PAJP]
# Preparar ato judicial (Padrão)
# Testa minutar despacho (inicial) [PAJP]
# Cumprimento de decisão
# Verificar urgência [CD]
# Cumprimento de decisão
# Verificar urgência [CD]
# Fluxo alteração de classe e fluxo com redistribuição
# Inicializar variaveis [FACFR]
# Seção de mutirão
# Triagem [SM]
# Preparar comunicação com controle de prazo
# Criar comunicação
# Preparar comunicação com controle de prazo
# Criar comunicação
# Preparar ato judicial (Padrão)
# Testa minutar despacho (inicial) [PAJP]
# Preparar ato judicial (Padrão)
# Testa minutar despacho (inicial) [PAJP]
# Cumprimento de decisão
# Verificar urgência [CD]
# Cumprimento de decisão
# Verificar urgência [CD]
# Preparar comunicação com controle de prazo
# Criar comunicação
# Preparar comunicação com controle de prazo
# Criar comunicação
# Preparar ato de cartório
# Inicializar variaveis [PRATCART]
# Preparar ato de cartório
# Inicializar variaveis [PRATCART]
# Preparar ato judicial em recurso
# Minutar decisão em recurso
# Preparar ato judicial em recurso
# Minutar decisão em recurso
# Remeter para instância superior
# Remeter para instância superior
# Remeter para instância superior
# Remeter para instância superior
# Realizar providências finais
# Verificar pendências finais [RPF]
# Realizar providências finais
# Verificar pendências finais [RPF]
# Deslocamento de processo para outro órgão
# Selecionar o órgão destino [DPO]
# Fluxo arquivo geral
# Gerar movimentação processo arquivado [AG]
# Fluxo cálculo da contadoria
# Analisar processo [CONT]
# Fluxo perícia apoio psicossocial
# Analisar processo [PAP]
# Fluxo partilha
# Analisar processo [PAR]
# Preparar ato ordinatório
# Preparar ato ordinatório
# Preparar ato de cartório
# Inicializar variaveis [PRATCART]
# Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# Fluxo equipe multidisciplinar
# Analisar processo [EMD]
# Fluxo do núcleo da infância e juventude
# Analisar processo [NIJ]
# Preparar ato ordinatório
# Preparar ato ordinatório
# Preparar ato de cartório
# Inicializar variaveis [PRATCART]
# Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# Avaliação de decisão proferida em execução fiscal
# Avalia existência de julgamento
# Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# Controle de prazos
# Testa existência de expedientes
# Preparar comunicação com controle de prazo
# Criar comunicação
# Preparar ato de cartório
# Inicializar variaveis [PRATCART]
# Preparar comunicação com controle de prazo
# Criar comunicação
# Preparar ato ordinatório
# Preparar ato ordinatório
# Preparar ato de cartório
# Inicializar variaveis [PRATCART]
# Preparar ato de cartório com revisor
# Inicializar variaveis [PRATCARTREV]
# Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# Controle de prazos
# Testa existência de expedientes
# Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# >>>>>>>>>> possível fluxo inexistente em: Preparar ato de comunicação
# Avaliação de bens
# Expedir mandado de avaliação
# Fluxo de bloqueio de ativos do devedor
# Preparar ordem de bloqueio
# Fluxo de liberação de ativos do devedor
# Preparar ordem de liberação
# Fluxo remeter para contadoria
# Testa contadoria Recife 01 [REMCONT]
# Preparar vários atos - Magistrado
# Testa fluxo novo [PVAM]
# Preparar vários atos - Secretaria
# Testa fluxo novo [PVAS]
# Preparar ato judicial
# Tipo de ato
# Cumprimento geral em execução fiscal
# Cumprir determinações
# Controle de prazos
# Testa existência de expedientes
# Cumprimento geral em execução fiscal
# Cumprir determinações
# Fluxo de bloqueio de ativos do devedor
# Preparar ordem de bloqueio
# Decisão com cumprimento simples
# Preparar decisão
# Preparar comunicação com controle de prazo
# Criar comunicação
# Preparar ato judicial
# Tipo de ato
# Fluxo de liberação de ativos do devedor
# Preparar ordem de liberação
# Fluxo remeter para contadoria
# Testa contadoria Recife 01 [REMCONT]
# Apreciação de recebimento de execução fiscal
# Testa deferimento
# Cumprimento de decisão em execução
# Separação em cumprimento de decisão em execução
# Preparar comunicação com controle de prazo
# Criar comunicação
# Preparar ato judicial
# Tipo de ato
# Avaliação de decisão proferida em execução fiscal
# Avalia existência de julgamento
# Fluxo alteração de classe e fluxo com redistribuição
# Inicializar variaveis [FACFR]
# Cumprimento geral em execução fiscal
# Cumprir determinações
# Preparar comunicação com controle de prazo
# Criar comunicação
# Remeter para instância superior
# Remeter para instância superior
# Preparar ato judicial em recurso
# Minutar decisão em recurso
# Fluxo arquivo geral
# Gerar movimentação processo arquivado [AG]
# Finalização de execução fiscal
# Verificar pendência em execução fiscal
# Deslocamento de processo para outro órgão
# Selecionar o órgão destino [DPO]
# Preparar ato judicial
# Tipo de ato
# Preparar comunicação com controle de prazo
# Criar comunicação
# Decisão com cumprimento simples
# Preparar decisão
# Preparar ato judicial em recurso
# Minutar decisão em recurso
# Cumprimento geral em execução fiscal
# Cumprir determinações
# Preparar ato judicial
# Tipo de ato
# Preparar ato de comunicação - SM
# Preparar comunicação [SM]

# %%
import hvplot.networkx as hvnx
import holoviews as hv
g.nodes.data()

# %%
# nx.write_graphml(g, "../graphos/Grapho_1_grau.graphml")
nx.write_graphml(g, '../graphos/Grapho_1_grau.xml')

# %%
lista = np.array(list(range(0,68)))
normalized_test_array = (lista - min(lista)) / (max(lista) - min(lista))
print((2 - 0) / (67 -0))
print(lista,'\n',normalized_test_array)
# df.Processo.unique().tolist() 
# from sklearn.preprocessing import MaxAbsScaler
# p=MaxAbsScaler()

# # # Analisa os dados e prepara o padronizador
# p.fit(lista)
# # # => MaxAbsScaler(copy=True)

# # Transforma os dados
# print(p.transform(lista))

# %%
np.where(df.Processo.unique().tolist()=='Fluxo arquivo geral da corregedoria')

# %%
from bokeh.models import HoverTool
hvnx.draw(g).opts(tools=[HoverTool(tooltips=[('index', '@index_hover')])])
hvnx.draw_spring(g, font_size='10pt', with_labels=False, alpha=0.4, node_color = nx.get_node_attributes(G,'val'), cmap=plt.cm.get_cmap('rainbow'), vmin=0, vmax=67,  width=800, height=800)
#font_size='10pt', node_color='Processo', cmap='Category10',

# %%
pos = nx.layout.spring_layout(g)

hvnx.draw(g, nodelist=df[df['Processo']=='Controle de Perícia']['No origem'], node_color='blue') *\
hvnx.draw(g,  nodelist=df[df['Processo']=='Controle de Perícia']['No origem'], node_color='blue') *\
hvnx.draw(g,  nodelist=df[df['Processo']=='Cumprimento de decisão']['No origem'], node_color='green') *\
hvnx.draw(g, nodelist=df[df['Processo']=='Cumprimento de decisão']['No destino'], node_color='green')

# %%
nx.get_node_attributes(g,'cor')

# %%
import numpy as np
import matplotlib.pyplot as plt

from bqplot import Graph, LinearScale, ColorScale, Figure, Tooltip
from ipywidgets import Layout

# %%
fig_layout = Layout(width='960px', height='500px')

# %%
node_data = g.nodes.data()
graph = Graph(node_data=node_data, link_data=link_data, charge=-600, colors=['orange'] * 7)
Figure(marks=[graph], layout=fig_layout)

# %%
import numpy as np
from bqplot import Graph, LinearScale, ColorScale, Figure, Tooltip
from ipywidgets import Layout

# %%
fig_layout = Layout(width='960px', height='500px')

# %%
node_data = list('ABCDEFG')
link_data = [{'source': s, 'target': t} for s, t in np.random.randint(0, 7, (10, 2))]
graph = Graph(node_data=node_data, link_data=link_data, charge=-600, colors=['orange'] * 7)
Figure(marks=[graph], layout=fig_layout)

# %%
node_data = [
    {'label': 'A', 'shape': 'circle', 'shape_attrs': {'r': 20}, 'foo': 1},
    {'label': 'Node B', 'shape': 'rect', 'shape_attrs': {'rx': 10, 'ry': 10, 'width': 40}, 'foo': 2},
    {'label': 'C', 'shape': 'ellipse', 'foo': 4},
    {'label': 'D', 'shape': 'rect', 'shape_attrs': {'width': 30, 'height': 30}, 'foo': 100, 'Raia':'Secretaria'},
]

link_data = [{'source': s, 'target': t, 'value': np.random.rand()} for s, t in np.random.randint(0, 4, (8, 2))]

graph = Graph(node_data=node_data, link_data=link_data, link_distance=150)
Figure(marks=[graph], layout=fig_layout)

# %%
tooltip = Tooltip(fields=['label', 'foo', 'Raia'], formats=['', '', ''])
graph.tooltip = tooltip

# %%
from pyvis.network import Network
import ne

g=NEtwork(height=800, width=800, notebook=True)
g.toggle_hide_edges_on_drag(True)
g.barnes_hut()
g.show("ex.html")
