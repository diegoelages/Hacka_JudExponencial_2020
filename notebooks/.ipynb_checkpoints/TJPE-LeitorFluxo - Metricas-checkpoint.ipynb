# %%
# Carrega as bibliotecas necessárias
import networkx as nx

# %%
#%run ./TJPE-LeitorFluxo-funcoes.ipynb
# Carrega o grapho
G = nx.read_graphml('../graphos/Grapho_1_grau.xml')

# %%
#Popularity
degree_centrality = nx.degree_centrality(G)

# %%
degree_centrality
# Out:
# {'Tarefa inicial': 0.05007153075822604,
#  'Remeter para instância superior': 0.005722460658082976,
#  'Registrar movimentação processo enviado': 0.001430615164520744,
#  'Fechar prazo de expediente': 0.002145922746781116,
#  'Registrar cancelamento remessa': 0.001430615164520744,
#  'Gerar movimentacao Fechamento de prazo expedientes': 0.001430615164520744,
#  'Término': 0.12732474964234622,
#  'Aguardando apreciação pela instância superior': 0.002861230329041488,
#  'Recebimento de instância superior': 0.001430615164520744,
#  'Definir tipo de arquivo definitivo [AJ]': 0.00357653791130186,
#  'Arquivo definitivo [AJ]': 0.002145922746781116,
#  'Definir tipo de arquivo definitivo (redistribuição) [AJ]': 0.002145922746781116,
#  'Arquivo definitivo (redistribuição) [AJ]': 0.002145922746781116,
#  'Definir tipo de arquivo definitivo (cancelamento de protocolamento) [AJ]': 0.002145922746781116,
#  'Arquivo definitivo (cancelamento de protocolamento) [AJ]': 0.002145922746781116,
# ...
